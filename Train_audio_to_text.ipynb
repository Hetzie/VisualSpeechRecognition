# %%
import gdown
url = 'https://drive.google.com/u/0/uc?id=1Qr3YGKdHVmT5Wfn25X2Ts2jE_XfcW1Yr&export=download'
output = 'dataset.zip'
gdown.download(url, output, quiet=False)
gdown.extractall('dataset.zip')
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1Qr3YGKdHVmT5Wfn25X2Ts2jE_XfcW1Yr&export=download
# To: /content/dataset.zip
# 100%|██████████| 358M/358M [00:08<00:00, 40.0MB/s]
# ['dataset/metadata.csv',
#  'dataset/waves/',
#  'dataset/waves/bbaf2n.wav',
#  'dataset/waves/bbaf3s.wav',
#  'dataset/waves/bbaf4p.wav',
#  'dataset/waves/bbaf5a.wav',
#  'dataset/waves/bbal6n.wav',
#  'dataset/waves/bbal7s.wav',
#  'dataset/waves/bbal8p.wav',
#  'dataset/waves/bbal9a.wav',
#  'dataset/waves/bbas1s.wav',
#  'dataset/waves/bbas2p.wav',
#  'dataset/waves/bbas3a.wav',
#  'dataset/waves/bbaszn.wav',
#  'dataset/waves/bbaz4n.wav',
#  'dataset/waves/bbaz5s.wav',
#  'dataset/waves/bbaz6p.wav',
#  'dataset/waves/bbaz7a.wav',
#  'dataset/waves/bbbf6n.wav',
#  'dataset/waves/bbbf7s.wav',
#  'dataset/waves/bbbf8p.wav',
#  'dataset/waves/bbbf9a.wav',
#  'dataset/waves/bbbm1s.wav',
#  'dataset/waves/bbbm2p.wav',
#  'dataset/waves/bbbm3a.wav',
#  'dataset/waves/bbbmzn.wav',
#  'dataset/waves/bbbs4n.wav',
#  'dataset/waves/bbbs5s.wav',
#  'dataset/waves/bbbs6p.wav',
#  'dataset/waves/bbbs7a.wav',
#  'dataset/waves/bbbz8n.wav',
#  'dataset/waves/bbbz9s.wav',
#  'dataset/waves/bbie8n.wav',
#  'dataset/waves/bbie9s.wav',
#  'dataset/waves/bbif1a.wav',
#  'dataset/waves/bbifzp.wav',
#  'dataset/waves/bbil2n.wav',
#  'dataset/waves/bbil3s.wav',
#  'dataset/waves/bbil4p.wav',
#  'dataset/waves/bbil5a.wav',
#  'dataset/waves/bbir6n.wav',
#  'dataset/waves/bbir7s.wav',
#  'dataset/waves/bbir8p.wav',
#  'dataset/waves/bbir9a.wav',
#  'dataset/waves/bbiz1s.wav',
#  'dataset/waves/bbiz2p.wav',
#  'dataset/waves/bbiz3a.wav',
#  'dataset/waves/bbizzn.wav',
#  'dataset/waves/bbwg1s.wav',
#  'dataset/waves/bbwg2p.wav',
#  'dataset/waves/bbwg3a.wav',
#  'dataset/waves/bbwgzn.wav',
#  'dataset/waves/bbwm4n.wav',
#  'dataset/waves/bbwm5s.wav',
#  'dataset/waves/bbwm6p.wav',
#  'dataset/waves/bbwm7a.wav',
#  'dataset/waves/bbws8n.wav',
#  'dataset/waves/bbws9s.wav',
#  'dataset/waves/bbwt1a.wav',
#  'dataset/waves/bbwtzp.wav',
#  'dataset/waves/bgaa6n.wav',
#  'dataset/waves/bgaa7s.wav',
#  'dataset/waves/bgaa8p.wav',
#  'dataset/waves/bgaa9a.wav',
#  'dataset/waves/bgah1s.wav',
#  'dataset/waves/bgah2p.wav',
#  'dataset/waves/bgah3a.wav',
#  'dataset/waves/bgahzn.wav',
#  'dataset/waves/bgan4n.wav',
#  'dataset/waves/bgan5s.wav',
#  'dataset/waves/bgan6p.wav',
#  'dataset/waves/bgan7a.wav',
#  'dataset/waves/bgat8n.wav',
#  'dataset/waves/bgat9s.wav',
#  'dataset/waves/bgau1a.wav',
#  'dataset/waves/bgauzp.wav',
#  'dataset/waves/bgbb1s.wav',
#  'dataset/waves/bgbb2p.wav',
#  'dataset/waves/bgbb3a.wav',
#  'dataset/waves/bgbbzn.wav',
#  'dataset/waves/bgbh4n.wav',
#  'dataset/waves/bgbh5s.wav',
#  'dataset/waves/bgbh6p.wav',
#  'dataset/waves/bgbh7a.wav',
#  'dataset/waves/bgbn8n.wav',
#  'dataset/waves/bgbn9s.wav',
#  'dataset/waves/bgbo1a.wav',
#  'dataset/waves/bgbozp.wav',
#  'dataset/waves/bgbu2n.wav',
#  'dataset/waves/bgbu3s.wav',
#  'dataset/waves/bgbu4p.wav',
#  'dataset/waves/bgbu5a.wav',
#  'dataset/waves/bgia2n.wav',
#  'dataset/waves/bgia3s.wav',
#  'dataset/waves/bgia4p.wav',
#  'dataset/waves/bgia5a.wav',
#  'dataset/waves/bgig6n.wav',
#  'dataset/waves/bgig7s.wav',
#  'dataset/waves/bgig8p.wav',
#  'dataset/waves/bgig9a.wav',
#  'dataset/waves/bgin1s.wav',
#  'dataset/waves/bgin2p.wav',
#  'dataset/waves/bgin3a.wav',
#  'dataset/waves/bginzn.wav',
#  'dataset/waves/bgit4n.wav',
#  'dataset/waves/bgit5s.wav',
#  'dataset/waves/bgit6p.wav',
#  'dataset/waves/bgit7a.wav',
#  'dataset/waves/bgwb4n.wav',
#  'dataset/waves/bgwb5s.wav',
#  'dataset/waves/bgwb6p.wav',
#  'dataset/waves/bgwb7a.wav',
#  'dataset/waves/bgwh8n.wav',
#  'dataset/waves/bgwh9s.wav',
#  'dataset/waves/bgwi1a.wav',
#  'dataset/waves/bgwizp.wav',
#  'dataset/waves/bgwo2n.wav',
#  'dataset/waves/bgwo3s.wav',
#  'dataset/waves/bgwo4p.wav',
#  'dataset/waves/bgwo5a.wav',
#  'dataset/waves/bgwu6n.wav',
#  'dataset/waves/bgwu7s.wav',
#  'dataset/waves/bgwu8p.wav',
#  'dataset/waves/bgwu9a.wav',
#  'dataset/waves/braf8n.wav',
#  'dataset/waves/braf9s.wav',
#  'dataset/waves/brag1a.wav',
#  'dataset/waves/bragzp.wav',
#  'dataset/waves/bram2n.wav',
#  'dataset/waves/bram3s.wav',
#  'dataset/waves/bram4p.wav',
#  'dataset/waves/bram5a.wav',
#  'dataset/waves/bras6n.wav',
#  'dataset/waves/bras7s.wav',
#  'dataset/waves/bras8p.wav',
#  'dataset/waves/bras9a.wav',
#  'dataset/waves/brba1a.wav',
#  'dataset/waves/brbazp.wav',
#  'dataset/waves/brbg2n.wav',
#  'dataset/waves/brbg3s.wav',
#  'dataset/waves/brbg4p.wav',
#  'dataset/waves/brbg5a.wav',
#  'dataset/waves/brbm6n.wav',
#  'dataset/waves/brbm7s.wav',
#  'dataset/waves/brbm8p.wav',
#  'dataset/waves/brbm9a.wav',
#  'dataset/waves/brbt1s.wav',
#  'dataset/waves/brbt2p.wav',
#  'dataset/waves/brbt3a.wav',
#  'dataset/waves/brbtzn.wav',
#  'dataset/waves/brif4n.wav',
#  'dataset/waves/brif5s.wav',
#  'dataset/waves/brif6p.wav',
#  'dataset/waves/brif7a.wav',
#  'dataset/waves/bril8n.wav',
#  'dataset/waves/bril9s.wav',
#  'dataset/waves/brim1a.wav',
#  'dataset/waves/brimzp.wav',
#  'dataset/waves/bris2n.wav',
#  'dataset/waves/bris3s.wav',
#  'dataset/waves/bris4p.wav',
#  'dataset/waves/bris5a.wav',
#  'dataset/waves/briz6n.wav',
#  'dataset/waves/briz7s.wav',
#  'dataset/waves/briz8p.wav',
#  'dataset/waves/briz9a.wav',
#  'dataset/waves/brwa2n.wav',
#  'dataset/waves/brwa3s.wav',
#  'dataset/waves/brwa4p.wav',
#  'dataset/waves/brwa5a.wav',
#  'dataset/waves/brwg6n.wav',
#  'dataset/waves/brwg7s.wav',
#  'dataset/waves/brwg8p.wav',
#  'dataset/waves/brwg9a.wav',
#  'dataset/waves/brwn1s.wav',
#  'dataset/waves/brwn2p.wav',
#  'dataset/waves/brwn3a.wav',
#  'dataset/waves/brwnzn.wav',
#  'dataset/waves/brwt4n.wav',
#  'dataset/waves/brwt5s.wav',
#  'dataset/waves/brwt6p.wav',
#  'dataset/waves/brwt7a.wav',
#  'dataset/waves/bwaa1s.wav',
#  'dataset/waves/bwaa2p.wav',
#  'dataset/waves/bwaa3a.wav',
#  'dataset/waves/bwaazn.wav',
#  'dataset/waves/bwag4n.wav',
#  'dataset/waves/bwag5s.wav',
#  'dataset/waves/bwag6p.wav',
#  'dataset/waves/bwag7a.wav',
#  'dataset/waves/bwam8n.wav',
#  'dataset/waves/bwam9s.wav',
#  'dataset/waves/bwan1a.wav',
#  'dataset/waves/bwanzp.wav',
#  'dataset/waves/bwat2n.wav',
#  'dataset/waves/bwat3s.wav',
#  'dataset/waves/bwat4p.wav',
#  'dataset/waves/bwat5a.wav',
#  'dataset/waves/bwba4n.wav',
#  'dataset/waves/bwba5s.wav',
#  'dataset/waves/bwba6p.wav',
#  'dataset/waves/bwba7a.wav',
#  'dataset/waves/bwbg8n.wav',
#  'dataset/waves/bwbg9s.wav',
#  'dataset/waves/bwbh1a.wav',
#  'dataset/waves/bwbhzp.wav',
#  'dataset/waves/bwbn2n.wav',
#  'dataset/waves/bwbn3s.wav',
#  'dataset/waves/bwbn4p.wav',
#  'dataset/waves/bwbn5a.wav',
#  'dataset/waves/bwbt6n.wav',
#  'dataset/waves/bwbt7s.wav',
#  'dataset/waves/bwbt8p.wav',
#  'dataset/waves/bwbt9a.wav',
#  'dataset/waves/bwig1s.wav',
#  'dataset/waves/bwig2p.wav',
#  'dataset/waves/bwig3a.wav',
#  'dataset/waves/bwigzn.wav',
#  'dataset/waves/bwim4n.wav',
#  'dataset/waves/bwim5s.wav',
#  'dataset/waves/bwim6p.wav',
#  'dataset/waves/bwim7a.wav',
#  'dataset/waves/bwis8n.wav',
#  'dataset/waves/bwis9s.wav',
#  'dataset/waves/bwit1a.wav',
#  'dataset/waves/bwitzp.wav',
#  'dataset/waves/bwwa8n.wav',
#  'dataset/waves/bwwa9s.wav',
#  'dataset/waves/bwwb1a.wav',
#  'dataset/waves/bwwbzp.wav',
#  'dataset/waves/bwwh2n.wav',
#  'dataset/waves/bwwh3s.wav',
#  'dataset/waves/bwwh4p.wav',
#  'dataset/waves/bwwh5a.wav',
#  'dataset/waves/bwwn6n.wav',
#  'dataset/waves/bwwn7s.wav',
#  'dataset/waves/bwwn8p.wav',
#  'dataset/waves/bwwn9a.wav',
#  'dataset/waves/bwwu1s.wav',
#  'dataset/waves/bwwu2p.wav',
#  'dataset/waves/bwwu3a.wav',
#  'dataset/waves/bwwuzn.wav',
#  'dataset/waves/lbad6n.wav',
#  'dataset/waves/lbad7s.wav',
#  'dataset/waves/lbad8p.wav',
#  'dataset/waves/lbad9a.wav',
#  'dataset/waves/lbak1s.wav',
#  'dataset/waves/lbak2p.wav',
#  'dataset/waves/lbak3a.wav',
#  'dataset/waves/lbakzn.wav',
#  'dataset/waves/lbaq4n.wav',
#  'dataset/waves/lbaq5s.wav',
#  'dataset/waves/lbaq6p.wav',
#  'dataset/waves/lbaq7a.wav',
#  'dataset/waves/lbax8n.wav',
#  'dataset/waves/lbax9s.wav',
#  'dataset/waves/lbay1a.wav',
#  'dataset/waves/lbayzp.wav',
#  'dataset/waves/lbbe1s.wav',
#  'dataset/waves/lbbe2p.wav',
#  'dataset/waves/lbbe3a.wav',
#  'dataset/waves/lbbezn.wav',
#  'dataset/waves/lbbk4n.wav',
#  'dataset/waves/lbbk5s.wav',
#  'dataset/waves/lbbk6p.wav',
#  'dataset/waves/lbbk7a.wav',
#  'dataset/waves/lbbq8n.wav',
#  'dataset/waves/lbbq9s.wav',
#  'dataset/waves/lbbr1a.wav',
#  'dataset/waves/lbbrzp.wav',
#  'dataset/waves/lbby2n.wav',
#  'dataset/waves/lbby3s.wav',
#  'dataset/waves/lbby4p.wav',
#  'dataset/waves/lbby5a.wav',
#  'dataset/waves/lbid2n.wav',
#  'dataset/waves/lbid3s.wav',
#  'dataset/waves/lbid4p.wav',
#  'dataset/waves/lbid5a.wav',
#  'dataset/waves/lbij6n.wav',
#  'dataset/waves/lbij7s.wav',
#  'dataset/waves/lbij8p.wav',
#  'dataset/waves/lbij9a.wav',
#  'dataset/waves/lbiq1s.wav',
#  'dataset/waves/lbiq2p.wav',
#  'dataset/waves/lbiq3a.wav',
#  'dataset/waves/lbiqzn.wav',
#  'dataset/waves/lbix4n.wav',
#  'dataset/waves/lbix5s.wav',
#  'dataset/waves/lbix6p.wav',
#  'dataset/waves/lbix7a.wav',
#  'dataset/waves/lbwe4n.wav',
#  'dataset/waves/lbwe5s.wav',
#  'dataset/waves/lbwe6p.wav',
#  'dataset/waves/lbwe7a.wav',
#  'dataset/waves/lbwk8n.wav',
#  'dataset/waves/lbwk9s.wav',
#  'dataset/waves/lbwl1a.wav',
#  'dataset/waves/lbwlzp.wav',
#  'dataset/waves/lbwr2n.wav',
#  'dataset/waves/lbwr3s.wav',
#  'dataset/waves/lbwr4p.wav',
#  'dataset/waves/lbwr5a.wav',
#  'dataset/waves/lbwy6n.wav',
#  'dataset/waves/lbwy7s.wav',
#  'dataset/waves/lbwy8p.wav',
#  'dataset/waves/lbwy9a.wav',
#  'dataset/waves/lgaf4n.wav',
#  'dataset/waves/lgaf5s.wav',
#  'dataset/waves/lgaf6p.wav',
#  'dataset/waves/lgaf7a.wav',
#  'dataset/waves/lgal8n.wav',
#  'dataset/waves/lgal9s.wav',
#  'dataset/waves/lgam1a.wav',
#  'dataset/waves/lgamzp.wav',
#  'dataset/waves/lgas2n.wav',
#  'dataset/waves/lgas3s.wav',
#  'dataset/waves/lgas4p.wav',
#  'dataset/waves/lgas5a.wav',
#  'dataset/waves/lgaz6n.wav',
#  'dataset/waves/lgaz7s.wav',
#  'dataset/waves/lgaz8p.wav',
#  'dataset/waves/lgaz9a.wav',
#  'dataset/waves/lgbf8n.wav',
#  'dataset/waves/lgbf9s.wav',
#  'dataset/waves/lgbg1a.wav',
#  'dataset/waves/lgbgzp.wav',
#  'dataset/waves/lgbm2n.wav',
#  'dataset/waves/lgbm3s.wav',
#  'dataset/waves/lgbm4p.wav',
#  'dataset/waves/lgbm5a.wav',
#  'dataset/waves/lgbs6n.wav',
#  'dataset/waves/lgbs7s.wav',
#  'dataset/waves/lgbs8p.wav',
#  'dataset/waves/lgbs9a.wav',
#  'dataset/waves/lgif1s.wav',
#  'dataset/waves/lgif2p.wav',
#  'dataset/waves/lgif3a.wav',
#  'dataset/waves/lgifzn.wav',
#  'dataset/waves/lgil4n.wav',
#  'dataset/waves/lgil5s.wav',
#  'dataset/waves/lgil6p.wav',
#  'dataset/waves/lgil7a.wav',
#  'dataset/waves/lgir8n.wav',
#  'dataset/waves/lgir9s.wav',
#  'dataset/waves/lgis1a.wav',
#  'dataset/waves/lgiszp.wav',
#  'dataset/waves/lgiz2n.wav',
#  'dataset/waves/lgiz3s.wav',
#  'dataset/waves/lgiz4p.wav',
#  'dataset/waves/lgiz5a.wav',
#  'dataset/waves/lgwa1a.wav',
#  'dataset/waves/lgwazp.wav',
#  'dataset/waves/lgwg2n.wav',
#  'dataset/waves/lgwg3s.wav',
#  'dataset/waves/lgwg4p.wav',
#  'dataset/waves/lgwg5a.wav',
#  'dataset/waves/lgwm6n.wav',
#  'dataset/waves/lgwm7s.wav',
#  'dataset/waves/lgwm8p.wav',
#  'dataset/waves/lgwm9a.wav',
#  'dataset/waves/lgwt1s.wav',
#  'dataset/waves/lgwt2p.wav',
#  'dataset/waves/lgwt3a.wav',
#  'dataset/waves/lgwtzn.wav',
#  'dataset/waves/lrae2n.wav',
#  'dataset/waves/lrae3s.wav',
#  'dataset/waves/lrae4p.wav',
#  'dataset/waves/lrae5a.wav',
#  'dataset/waves/lrak6n.wav',
#  'dataset/waves/lrak7s.wav',
#  'dataset/waves/lrak8p.wav',
#  'dataset/waves/lrak9a.wav',
#  'dataset/waves/lrar1s.wav',
#  'dataset/waves/lrar2p.wav',
#  'dataset/waves/lrar3a.wav',
#  'dataset/waves/lrarzn.wav',
#  'dataset/waves/lray4n.wav',
#  'dataset/waves/lray5s.wav',
#  'dataset/waves/lray6p.wav',
#  'dataset/waves/lray7a.wav',
#  'dataset/waves/lrbe6n.wav',
#  'dataset/waves/lrbe7s.wav',
#  'dataset/waves/lrbe8p.wav',
#  'dataset/waves/lrbe9a.wav',
#  'dataset/waves/lrbl1s.wav',
#  'dataset/waves/lrbl2p.wav',
#  'dataset/waves/lrbl3a.wav',
#  'dataset/waves/lrblzn.wav',
#  'dataset/waves/lrbr4n.wav',
#  'dataset/waves/lrbr5s.wav',
#  'dataset/waves/lrbr6p.wav',
#  'dataset/waves/lrbr7a.wav',
#  'dataset/waves/lrby8n.wav',
#  'dataset/waves/lrby9s.wav',
#  'dataset/waves/lrbz1a.wav',
#  'dataset/waves/lrbzzp.wav',
#  'dataset/waves/lrid8n.wav',
#  'dataset/waves/lrid9s.wav',
#  'dataset/waves/lrie1a.wav',
#  'dataset/waves/lriezp.wav',
#  'dataset/waves/lrik2n.wav',
#  'dataset/waves/lrik3s.wav',
#  'dataset/waves/lrik4p.wav',
#  'dataset/waves/lrik5a.wav',
#  'dataset/waves/lriq6n.wav',
#  'dataset/waves/lriq7s.wav',
#  'dataset/waves/lriq8p.wav',
#  'dataset/waves/lriq9a.wav',
#  'dataset/waves/lriy1s.wav',
#  'dataset/waves/lriy2p.wav',
#  'dataset/waves/lriy3a.wav',
#  'dataset/waves/lriyzn.wav',
#  'dataset/waves/lrwf1s.wav',
#  'dataset/waves/lrwf2p.wav',
#  'dataset/waves/lrwf3a.wav',
#  'dataset/waves/lrwfzn.wav',
#  'dataset/waves/lrwl4n.wav',
#  'dataset/waves/lrwl5s.wav',
#  'dataset/waves/lrwl6p.wav',
#  'dataset/waves/lrwl7a.wav',
#  'dataset/waves/lrwr8n.wav',
#  'dataset/waves/lrwr9s.wav',
#  'dataset/waves/lrws1a.wav',
#  'dataset/waves/lrwszp.wav',
#  'dataset/waves/lrwz2n.wav',
#  'dataset/waves/lrwz3s.wav',
#  'dataset/waves/lrwz4p.wav',
#  'dataset/waves/lrwz5a.wav',
#  'dataset/waves/lwae8n.wav',
#  'dataset/waves/lwae9s.wav',
#  'dataset/waves/lwaf1a.wav',
#  'dataset/waves/lwafzp.wav',
#  'dataset/waves/lwal2n.wav',
#  'dataset/waves/lwal3s.wav',
#  'dataset/waves/lwal4p.wav',
#  'dataset/waves/lwal5a.wav',
#  'dataset/waves/lwar6n.wav',
#  'dataset/waves/lwar7s.wav',
#  'dataset/waves/lwar8p.wav',
#  'dataset/waves/lwar9a.wav',
#  'dataset/waves/lwaz1s.wav',
#  'dataset/waves/lwaz2p.wav',
#  'dataset/waves/lwaz3a.wav',
#  'dataset/waves/lwazzn.wav',
#  'dataset/waves/lwbf2n.wav',
#  'dataset/waves/lwbf3s.wav',
#  'dataset/waves/lwbf4p.wav',
#  'dataset/waves/lwbf5a.wav',
#  'dataset/waves/lwbl6n.wav',
#  'dataset/waves/lwbl7s.wav',
#  'dataset/waves/lwbl8p.wav',
#  'dataset/waves/lwbl9a.wav',
#  'dataset/waves/lwbs1s.wav',
#  'dataset/waves/lwbs2p.wav',
#  'dataset/waves/lwbs3a.wav',
#  'dataset/waves/lwbszn.wav',
#  'dataset/waves/lwbz4n.wav',
#  'dataset/waves/lwbz5s.wav',
#  'dataset/waves/lwbz6p.wav',
#  'dataset/waves/lwbz7a.wav',
#  'dataset/waves/lwie4n.wav',
#  'dataset/waves/lwie5s.wav',
#  'dataset/waves/lwie6p.wav',
#  'dataset/waves/lwie7a.wav',
#  'dataset/waves/lwik8n.wav',
#  'dataset/waves/lwik9s.wav',
#  'dataset/waves/lwil1a.wav',
#  'dataset/waves/lwilzp.wav',
#  'dataset/waves/lwir2n.wav',
#  'dataset/waves/lwir3s.wav',
#  'dataset/waves/lwir4p.wav',
#  'dataset/waves/lwir5a.wav',
#  'dataset/waves/lwiy6n.wav',
#  'dataset/waves/lwiy7s.wav',
#  'dataset/waves/lwiy8p.wav',
#  'dataset/waves/lwiy9a.wav',
#  'dataset/waves/lwwf6n.wav',
#  'dataset/waves/lwwf7s.wav',
#  'dataset/waves/lwwf8p.wav',
#  'dataset/waves/lwwf9a.wav',
#  'dataset/waves/lwwm1s.wav',
#  'dataset/waves/lwwm2p.wav',
#  'dataset/waves/lwwm3a.wav',
#  'dataset/waves/lwwmzn.wav',
#  'dataset/waves/lwws4n.wav',
#  'dataset/waves/lwws5s.wav',
#  'dataset/waves/lwws6p.wav',
#  'dataset/waves/lwws7a.wav',
#  'dataset/waves/lwwz8n.wav',
#  'dataset/waves/lwwz9s.wav',
#  'dataset/waves/pbac1s.wav',
#  'dataset/waves/pbac2p.wav',
#  'dataset/waves/pbac3a.wav',
#  'dataset/waves/pbaczn.wav',
#  'dataset/waves/pbai4n.wav',
#  'dataset/waves/pbai5s.wav',
#  'dataset/waves/pbai6p.wav',
#  'dataset/waves/pbai7a.wav',
#  'dataset/waves/pbao8n.wav',
#  'dataset/waves/pbao9s.wav',
#  'dataset/waves/pbap1a.wav',
#  'dataset/waves/pbapzp.wav',
#  'dataset/waves/pbav2n.wav',
#  'dataset/waves/pbav3s.wav',
#  'dataset/waves/pbav4p.wav',
#  'dataset/waves/pbav5a.wav',
#  'dataset/waves/pbbc4n.wav',
#  'dataset/waves/pbbc5s.wav',
#  'dataset/waves/pbbc6p.wav',
#  'dataset/waves/pbbc7a.wav',
#  'dataset/waves/pbbi8n.wav',
#  'dataset/waves/pbbi9s.wav',
#  'dataset/waves/pbbj1a.wav',
#  'dataset/waves/pbbjzp.wav',
#  'dataset/waves/pbbp2n.wav',
#  'dataset/waves/pbbp3s.wav',
#  'dataset/waves/pbbp4p.wav',
#  'dataset/waves/pbbp5a.wav',
#  'dataset/waves/pbbv6n.wav',
#  'dataset/waves/pbbv7s.wav',
#  'dataset/waves/pbbv8p.wav',
#  'dataset/waves/pbbv9a.wav',
#  'dataset/waves/pbib6n.wav',
#  'dataset/waves/pbib7s.wav',
#  'dataset/waves/pbib8p.wav',
#  'dataset/waves/pbib9a.wav',
#  'dataset/waves/pbii1s.wav',
#  'dataset/waves/pbii2p.wav',
#  'dataset/waves/pbii3a.wav',
#  'dataset/waves/pbiizn.wav',
#  'dataset/waves/pbio4n.wav',
#  'dataset/waves/pbio5s.wav',
#  'dataset/waves/pbio6p.wav',
#  'dataset/waves/pbio7a.wav',
#  'dataset/waves/pbiu8n.wav',
#  'dataset/waves/pbiu9s.wav',
#  'dataset/waves/pbiv1a.wav',
#  'dataset/waves/pbivzp.wav',
#  'dataset/waves/pbwc8n.wav',
#  'dataset/waves/pbwc9s.wav',
#  'dataset/waves/pbwd1a.wav',
#  'dataset/waves/pbwdzp.wav',
#  'dataset/waves/pbwj2n.wav',
#  'dataset/waves/pbwj3s.wav',
#  'dataset/waves/pbwj4p.wav',
#  'dataset/waves/pbwj5a.wav',
#  'dataset/waves/pbwp6n.wav',
#  'dataset/waves/pbwp7s.wav',
#  'dataset/waves/pbwp8p.wav',
#  'dataset/waves/pbwp9a.wav',
#  'dataset/waves/pbwx1s.wav',
#  'dataset/waves/pbwx2p.wav',
#  'dataset/waves/pbwx3a.wav',
#  'dataset/waves/pbwxzn.wav',
#  'dataset/waves/pgad8n.wav',
#  'dataset/waves/pgad9s.wav',
#  'dataset/waves/pgae1a.wav',
#  'dataset/waves/pgaezp.wav',
#  'dataset/waves/pgak2n.wav',
#  'dataset/waves/pgak3s.wav',
#  'dataset/waves/pgak4p.wav',
#  'dataset/waves/pgak5a.wav',
#  'dataset/waves/pgaq6n.wav',
#  'dataset/waves/pgaq7s.wav',
#  'dataset/waves/pgaq8p.wav',
#  'dataset/waves/pgaq9a.wav',
#  'dataset/waves/pgay1s.wav',
#  'dataset/waves/pgay2p.wav',
#  'dataset/waves/pgay3a.wav',
#  'dataset/waves/pgayzn.wav',
#  'dataset/waves/pgbe2n.wav',
#  'dataset/waves/pgbe3s.wav',
#  'dataset/waves/pgbe4p.wav',
#  'dataset/waves/pgbe5a.wav',
#  'dataset/waves/pgbk6n.wav',
#  'dataset/waves/pgbk7s.wav',
#  'dataset/waves/pgbk8p.wav',
#  'dataset/waves/pgbk9a.wav',
#  'dataset/waves/pgbr1s.wav',
#  'dataset/waves/pgbr2p.wav',
#  'dataset/waves/pgbr3a.wav',
#  'dataset/waves/pgbrzn.wav',
#  'dataset/waves/pgby4n.wav',
#  'dataset/waves/pgby5s.wav',
#  'dataset/waves/pgby6p.wav',
#  'dataset/waves/pgby7a.wav',
#  'dataset/waves/pgid4n.wav',
#  'dataset/waves/pgid5s.wav',
#  'dataset/waves/pgid6p.wav',
#  'dataset/waves/pgid7a.wav',
#  'dataset/waves/pgij8n.wav',
#  'dataset/waves/pgij9s.wav',
#  'dataset/waves/pgik1a.wav',
#  'dataset/waves/pgikzp.wav',
#  'dataset/waves/pgiq2n.wav',
#  'dataset/waves/pgiq3s.wav',
#  'dataset/waves/pgiq4p.wav',
#  'dataset/waves/pgiq5a.wav',
#  'dataset/waves/pgix6n.wav',
#  'dataset/waves/pgix7s.wav',
#  'dataset/waves/pgix8p.wav',
#  'dataset/waves/pgix9a.wav',
#  'dataset/waves/pgwe6n.wav',
#  'dataset/waves/pgwe7s.wav',
#  'dataset/waves/pgwe8p.wav',
#  'dataset/waves/pgwe9a.wav',
#  'dataset/waves/pgwl1s.wav',
#  'dataset/waves/pgwl2p.wav',
#  'dataset/waves/pgwl3a.wav',
#  'dataset/waves/pgwlzn.wav',
#  'dataset/waves/pgwr4n.wav',
#  'dataset/waves/pgwr5s.wav',
#  'dataset/waves/pgwr6p.wav',
#  'dataset/waves/pgwr7a.wav',
#  'dataset/waves/pgwy8n.wav',
#  'dataset/waves/pgwy9s.wav',
#  'dataset/waves/pgwz1a.wav',
#  'dataset/waves/pgwzzp.wav',
#  'dataset/waves/prac6n.wav',
#  'dataset/waves/prac7s.wav',
#  'dataset/waves/prac8p.wav',
#  'dataset/waves/prac9a.wav',
#  'dataset/waves/praj1s.wav',
#  'dataset/waves/praj2p.wav',
#  'dataset/waves/praj3a.wav',
#  'dataset/waves/prajzn.wav',
#  'dataset/waves/prap4n.wav',
#  'dataset/waves/prap5s.wav',
#  'dataset/waves/prap6p.wav',
#  'dataset/waves/prap7a.wav',
#  'dataset/waves/prav8n.wav',
#  'dataset/waves/prav9s.wav',
#  'dataset/waves/prax1a.wav',
#  'dataset/waves/praxzp.wav',
#  'dataset/waves/prbd1s.wav',
#  'dataset/waves/prbd2p.wav',
#  'dataset/waves/prbd3a.wav',
#  'dataset/waves/prbdzn.wav',
#  'dataset/waves/prbj4n.wav',
#  'dataset/waves/prbj5s.wav',
#  'dataset/waves/prbj6p.wav',
#  'dataset/waves/prbj7a.wav',
#  'dataset/waves/prbp8n.wav',
#  'dataset/waves/prbp9s.wav',
#  'dataset/waves/prbq1a.wav',
#  'dataset/waves/prbqzp.wav',
#  'dataset/waves/prbx2n.wav',
#  'dataset/waves/prbx3s.wav',
#  'dataset/waves/prbx4p.wav',
#  'dataset/waves/prbx5a.wav',
#  'dataset/waves/pric2n.wav',
#  'dataset/waves/pric3s.wav',
#  'dataset/waves/pric4p.wav',
#  'dataset/waves/pric5a.wav',
#  'dataset/waves/prii6n.wav',
#  'dataset/waves/prii7s.wav',
#  'dataset/waves/prii8p.wav',
#  'dataset/waves/prii9a.wav',
#  'dataset/waves/prip1s.wav',
#  'dataset/waves/prip2p.wav',
#  'dataset/waves/prip3a.wav',
#  'dataset/waves/pripzn.wav',
#  'dataset/waves/priv4n.wav',
#  'dataset/waves/priv5s.wav',
#  'dataset/waves/priv6p.wav',
#  'dataset/waves/priv7a.wav',
#  'dataset/waves/prwd4n.wav',
#  'dataset/waves/prwd5s.wav',
#  'dataset/waves/prwd6p.wav',
#  'dataset/waves/prwd7a.wav',
#  'dataset/waves/prwj8n.wav',
#  'dataset/waves/prwj9s.wav',
#  'dataset/waves/prwk1a.wav',
#  'dataset/waves/prwkzp.wav',
#  'dataset/waves/prwq2n.wav',
#  'dataset/waves/prwq3s.wav',
#  'dataset/waves/prwq4p.wav',
#  'dataset/waves/prwq5a.wav',
#  'dataset/waves/prwx6n.wav',
#  'dataset/waves/prwx7s.wav',
#  'dataset/waves/prwx8p.wav',
#  'dataset/waves/prwx9a.wav',
#  'dataset/waves/pwad2n.wav',
#  'dataset/waves/pwad3s.wav',
#  'dataset/waves/pwad4p.wav',
#  'dataset/waves/pwad5a.wav',
#  'dataset/waves/pwaj6n.wav',
#  'dataset/waves/pwaj7s.wav',
#  'dataset/waves/pwaj8p.wav',
#  'dataset/waves/pwaj9a.wav',
#  'dataset/waves/pwaq1s.wav',
#  'dataset/waves/pwaq2p.wav',
#  'dataset/waves/pwaq3a.wav',
#  'dataset/waves/pwaqzn.wav',
#  'dataset/waves/pwax4n.wav',
#  'dataset/waves/pwax5s.wav',
#  'dataset/waves/pwax6p.wav',
#  'dataset/waves/pwax7a.wav',
#  'dataset/waves/pwbd6n.wav',
#  'dataset/waves/pwbd7s.wav',
#  'dataset/waves/pwbd8p.wav',
#  'dataset/waves/pwbd9a.wav',
#  'dataset/waves/pwbk1s.wav',
#  'dataset/waves/pwbk2p.wav',
#  'dataset/waves/pwbk3a.wav',
#  'dataset/waves/pwbkzn.wav',
#  'dataset/waves/pwbq4n.wav',
#  'dataset/waves/pwbq5s.wav',
#  'dataset/waves/pwbq6p.wav',
#  'dataset/waves/pwbq7a.wav',
#  'dataset/waves/pwbx8n.wav',
#  'dataset/waves/pwbx9s.wav',
#  'dataset/waves/pwby1a.wav',
#  'dataset/waves/pwbyzp.wav',
#  'dataset/waves/pwic8n.wav',
#  'dataset/waves/pwic9s.wav',
#  'dataset/waves/pwid1a.wav',
#  'dataset/waves/pwidzp.wav',
#  'dataset/waves/pwij2n.wav',
#  'dataset/waves/pwij3s.wav',
#  'dataset/waves/pwij4p.wav',
#  'dataset/waves/pwij5a.wav',
#  'dataset/waves/pwip6n.wav',
#  'dataset/waves/pwip7s.wav',
#  'dataset/waves/pwip8p.wav',
#  'dataset/waves/pwip9a.wav',
#  'dataset/waves/pwix1s.wav',
#  'dataset/waves/pwix2p.wav',
#  'dataset/waves/pwix3a.wav',
#  'dataset/waves/pwixzn.wav',
#  'dataset/waves/pwwe1s.wav',
#  'dataset/waves/pwwe2p.wav',
#  'dataset/waves/pwwe3a.wav',
#  'dataset/waves/pwwezn.wav',
#  'dataset/waves/pwwk4n.wav',
#  'dataset/waves/pwwk5s.wav',
#  'dataset/waves/pwwk6p.wav',
#  'dataset/waves/pwwk7a.wav',
#  'dataset/waves/pwwq8n.wav',
#  'dataset/waves/pwwq9s.wav',
#  'dataset/waves/pwwr1a.wav',
#  'dataset/waves/pwwrzp.wav',
#  'dataset/waves/pwwy2n.wav',
#  'dataset/waves/pwwy3s.wav',
#  'dataset/waves/pwwy4p.wav',
#  'dataset/waves/pwwy5a.wav',
#  'dataset/waves/sbaa4n.wav',
#  'dataset/waves/sbaa5s.wav',
#  'dataset/waves/sbaa6p.wav',
#  'dataset/waves/sbaa7a.wav',
#  'dataset/waves/sbag8n.wav',
#  'dataset/waves/sbag9s.wav',
#  'dataset/waves/sbah1a.wav',
#  'dataset/waves/sbahzp.wav',
#  'dataset/waves/sban2n.wav',
#  'dataset/waves/sban3s.wav',
#  'dataset/waves/sban4p.wav',
#  'dataset/waves/sban5a.wav',
#  'dataset/waves/sbat6n.wav',
#  'dataset/waves/sbat7s.wav',
#  'dataset/waves/sbat8p.wav',
#  'dataset/waves/sbat9a.wav',
#  'dataset/waves/sbba8n.wav',
#  'dataset/waves/sbba9s.wav',
#  'dataset/waves/sbbb1a.wav',
#  'dataset/waves/sbbbzp.wav',
#  'dataset/waves/sbbh2n.wav',
#  'dataset/waves/sbbh3s.wav',
#  'dataset/waves/sbbh4p.wav',
#  'dataset/waves/sbbh5a.wav',
#  'dataset/waves/sbbn6n.wav',
#  'dataset/waves/sbbn7s.wav',
#  'dataset/waves/sbbn8p.wav',
#  'dataset/waves/sbbn9a.wav',
#  'dataset/waves/sbbu1s.wav',
#  'dataset/waves/sbbu2p.wav',
#  'dataset/waves/sbbu3a.wav',
#  'dataset/waves/sbbuzn.wav',
#  'dataset/waves/sbia1s.wav',
#  'dataset/waves/sbia2p.wav',
#  'dataset/waves/sbia3a.wav',
#  'dataset/waves/sbiazn.wav',
#  'dataset/waves/sbig4n.wav',
#  'dataset/waves/sbig5s.wav',
#  'dataset/waves/sbig6p.wav',
#  'dataset/waves/sbig7a.wav',
#  'dataset/waves/sbim8n.wav',
#  'dataset/waves/sbim9s.wav',
#  'dataset/waves/sbin1a.wav',
#  'dataset/waves/sbinzp.wav',
#  'dataset/waves/sbit2n.wav',
#  'dataset/waves/sbit3s.wav',
#  'dataset/waves/sbit4p.wav',
#  'dataset/waves/sbit5a.wav',
#  'dataset/waves/sbwb2n.wav',
#  'dataset/waves/sbwb3s.wav',
#  'dataset/waves/sbwb4p.wav',
#  'dataset/waves/sbwb5a.wav',
#  'dataset/waves/sbwh6n.wav',
#  'dataset/waves/sbwh7s.wav',
#  'dataset/waves/sbwh8p.wav',
#  'dataset/waves/sbwh9a.wav',
#  'dataset/waves/sbwo1s.wav',
#  'dataset/waves/sbwo2p.wav',
#  'dataset/waves/sbwo3a.wav',
#  'dataset/waves/sbwozn.wav',
#  'dataset/waves/sbwu4n.wav',
#  'dataset/waves/sbwu5s.wav',
#  'dataset/waves/sbwu6p.wav',
#  'dataset/waves/sbwu7a.wav',
#  'dataset/waves/sgac2n.wav',
#  'dataset/waves/sgac3s.wav',
#  'dataset/waves/sgac4p.wav',
#  'dataset/waves/sgac5a.wav',
#  'dataset/waves/sgai6n.wav',
#  'dataset/waves/sgai7s.wav',
#  'dataset/waves/sgai8p.wav',
#  'dataset/waves/sgai9a.wav',
#  'dataset/waves/sgap1s.wav',
#  'dataset/waves/sgap2p.wav',
#  'dataset/waves/sgap3a.wav',
#  'dataset/waves/sgapzn.wav',
#  'dataset/waves/sgav4n.wav',
#  'dataset/waves/sgav5s.wav',
#  'dataset/waves/sgav6p.wav',
#  'dataset/waves/sgav7a.wav',
#  'dataset/waves/sgbc6n.wav',
#  'dataset/waves/sgbc7s.wav',
#  'dataset/waves/sgbc8p.wav',
#  'dataset/waves/sgbc9a.wav',
#  'dataset/waves/sgbj1s.wav',
#  'dataset/waves/sgbj2p.wav',
#  'dataset/waves/sgbj3a.wav',
#  'dataset/waves/sgbjzn.wav',
#  'dataset/waves/sgbp4n.wav',
#  'dataset/waves/sgbp5s.wav',
#  'dataset/waves/sgbp6p.wav',
#  'dataset/waves/sgbp7a.wav',
#  'dataset/waves/sgbv8n.wav',
#  'dataset/waves/sgbv9s.wav',
#  'dataset/waves/sgbx1a.wav',
#  'dataset/waves/sgbxzp.wav',
#  'dataset/waves/sgib8n.wav',
#  'dataset/waves/sgib9s.wav',
#  'dataset/waves/sgic1a.wav',
#  'dataset/waves/sgiczp.wav',
#  'dataset/waves/sgii2n.wav',
#  'dataset/waves/sgii3s.wav',
#  'dataset/waves/sgii4p.wav',
#  'dataset/waves/sgii5a.wav',
#  'dataset/waves/sgio6n.wav',
#  'dataset/waves/sgio7s.wav',
#  'dataset/waves/sgio8p.wav',
#  'dataset/waves/sgio9a.wav',
#  'dataset/waves/sgiv1s.wav',
#  'dataset/waves/sgiv2p.wav',
#  'dataset/waves/sgiv3a.wav',
#  'dataset/waves/sgivzn.wav',
#  'dataset/waves/sgwd1s.wav',
#  'dataset/waves/sgwd2p.wav',
#  'dataset/waves/sgwd3a.wav',
#  'dataset/waves/sgwdzn.wav',
#  'dataset/waves/sgwj4n.wav',
#  'dataset/waves/sgwj5s.wav',
#  'dataset/waves/sgwj6p.wav',
#  'dataset/waves/sgwj7a.wav',
#  'dataset/waves/sgwp8n.wav',
#  'dataset/waves/sgwp9s.wav',
#  'dataset/waves/sgwq1a.wav',
#  'dataset/waves/sgwqzp.wav',
#  'dataset/waves/sgwx2n.wav',
#  'dataset/waves/sgwx3s.wav',
#  'dataset/waves/sgwx4p.wav',
#  'dataset/waves/sgwx5a.wav',
#  'dataset/waves/srab1s.wav',
#  'dataset/waves/srab2p.wav',
#  'dataset/waves/srab3a.wav',
#  'dataset/waves/srabzn.wav',
#  'dataset/waves/srah4n.wav',
#  'dataset/waves/srah5s.wav',
#  'dataset/waves/srah6p.wav',
#  'dataset/waves/srah7a.wav',
#  'dataset/waves/sran8n.wav',
#  'dataset/waves/sran9s.wav',
#  'dataset/waves/srao1a.wav',
#  'dataset/waves/sraozp.wav',
#  'dataset/waves/srau2n.wav',
#  'dataset/waves/srau3s.wav',
#  'dataset/waves/srau4p.wav',
#  'dataset/waves/srau5a.wav',
#  'dataset/waves/srbb4n.wav',
#  'dataset/waves/srbb5s.wav',
#  'dataset/waves/srbb6p.wav',
#  'dataset/waves/srbb7a.wav',
#  'dataset/waves/srbh8n.wav',
#  'dataset/waves/srbh9s.wav',
#  'dataset/waves/srbi1a.wav',
#  'dataset/waves/srbizp.wav',
#  'dataset/waves/srbo2n.wav',
#  'dataset/waves/srbo3s.wav',
#  'dataset/waves/srbo4p.wav',
#  'dataset/waves/srbo5a.wav',
#  'dataset/waves/srbu6n.wav',
#  'dataset/waves/srbu7s.wav',
#  'dataset/waves/srbu8p.wav',
#  'dataset/waves/srbu9a.wav',
#  'dataset/waves/sria6n.wav',
#  'dataset/waves/sria7s.wav',
#  'dataset/waves/sria8p.wav',
#  'dataset/waves/sria9a.wav',
#  'dataset/waves/srih1s.wav',
#  'dataset/waves/srih2p.wav',
#  'dataset/waves/srih3a.wav',
#  'dataset/waves/srihzn.wav',
#  'dataset/waves/srin4n.wav',
#  'dataset/waves/srin5s.wav',
#  'dataset/waves/srin6p.wav',
#  'dataset/waves/srin7a.wav',
#  'dataset/waves/srit8n.wav',
#  'dataset/waves/srit9s.wav',
#  'dataset/waves/sriu1a.wav',
#  'dataset/waves/sriuzp.wav',
#  'dataset/waves/srwb8n.wav',
#  'dataset/waves/srwb9s.wav',
#  'dataset/waves/srwc1a.wav',
#  'dataset/waves/srwczp.wav',
#  'dataset/waves/srwi2n.wav',
#  'dataset/waves/srwi3s.wav',
#  'dataset/waves/srwi4p.wav',
#  'dataset/waves/srwi5a.wav',
#  'dataset/waves/srwo6n.wav',
#  'dataset/waves/srwo7s.wav',
#  'dataset/waves/srwo8p.wav',
#  'dataset/waves/srwo9a.wav',
#  'dataset/waves/srwv1s.wav',
#  'dataset/waves/srwv2p.wav',
#  'dataset/waves/srwv3a.wav',
#  'dataset/waves/srwvzn.wav',
#  'dataset/waves/swab6n.wav',
#  'dataset/waves/swab7s.wav',
#  'dataset/waves/swab8p.wav',
#  'dataset/waves/swab9a.wav',
#  'dataset/waves/swai1s.wav',
#  'dataset/waves/swai2p.wav',
#  'dataset/waves/swai3a.wav',
#  'dataset/waves/swaizn.wav',
#  'dataset/waves/swao4n.wav',
#  'dataset/waves/swao5s.wav',
#  'dataset/waves/swao6p.wav',
#  'dataset/waves/swao7a.wav',
#  'dataset/waves/swau8n.wav',
#  'dataset/waves/swau9s.wav',
#  'dataset/waves/swav1a.wav',
#  'dataset/waves/swavzp.wav',
#  'dataset/waves/swbc1s.wav',
#  'dataset/waves/swbc2p.wav',
#  'dataset/waves/swbc3a.wav',
#  'dataset/waves/swbczn.wav',
#  'dataset/waves/swbi4n.wav',
#  'dataset/waves/swbi5s.wav',
#  'dataset/waves/swbi6p.wav',
#  'dataset/waves/swbi7a.wav',
#  'dataset/waves/swbo8n.wav',
#  'dataset/waves/swbo9s.wav',
#  'dataset/waves/swbp1a.wav',
#  'dataset/waves/swbpzp.wav',
#  'dataset/waves/swbv2n.wav',
#  'dataset/waves/swbv3s.wav',
#  'dataset/waves/swbv4p.wav',
#  'dataset/waves/swbv5a.wav',
#  'dataset/waves/swib2n.wav',
#  'dataset/waves/swib3s.wav',
#  'dataset/waves/swib4p.wav',
#  'dataset/waves/swib5a.wav',
#  'dataset/waves/swih6n.wav',
#  'dataset/waves/swih7s.wav',
#  'dataset/waves/swih8p.wav',
#  'dataset/waves/swih9a.wav',
#  'dataset/waves/swio1s.wav',
#  'dataset/waves/swio2p.wav',
#  'dataset/waves/swio3a.wav',
#  'dataset/waves/swiozn.wav',
#  'dataset/waves/swiu4n.wav',
#  'dataset/waves/swiu5s.wav',
#  'dataset/waves/swiu6p.wav',
#  'dataset/waves/swiu7a.wav',
#  'dataset/waves/swwc4n.wav',
#  'dataset/waves/swwc5s.wav',
#  'dataset/waves/swwc6p.wav',
#  'dataset/waves/swwc7a.wav',
#  'dataset/waves/swwi8n.wav',
#  'dataset/waves/swwi9s.wav',
#  'dataset/waves/swwj1a.wav',
#  'dataset/waves/swwjzp.wav',
#  'dataset/waves/swwp2n.wav',
#  'dataset/waves/swwp3s.wav',
#  'dataset/waves/swwp4p.wav',
#  'dataset/waves/swwp5a.wav',
#  'dataset/waves/swwv6n.wav',
#  'dataset/waves/swwv7s.wav',
#  ...]

# %%
# !pip install mltu
# Out:
# Requirement already satisfied: mltu in /usr/local/lib/python3.10/dist-packages (1.1.4)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mltu) (4.66.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mltu) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mltu) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from mltu) (4.8.0.76)
# Requirement already satisfied: Pillow>=9.4.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (9.4.0)
# Requirement already satisfied: onnxruntime>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mltu) (3.7.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (1.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mltu) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mltu) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.15.0->mltu) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.0->mltu) (1.3.0)

# %%
# !pip install tf2onnx
# Out:
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.10/dist-packages (1.15.1)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.23.5)
# Requirement already satisfied: onnx>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (23.5.26)
# Requirement already satisfied: protobuf~=3.20.2 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.4.1->tf2onnx) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2023.7.22)

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)

# %%
import tensorflow as tf


import os
import tarfile
import pandas as pd
from tqdm import tqdm
from urllib.request import urlopen
from io import BytesIO

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from mltu.preprocessors import WavReader

from mltu.tensorflow.dataProvider import DataProvider
from mltu.transformers import LabelIndexer, LabelPadding, SpectrogramPadding
from mltu.tensorflow.losses import CTCloss
from mltu.tensorflow.callbacks import Model2onnx, TrainLogger
from mltu.tensorflow.metrics import CERMetric, WERMetric

# %%
import h5py

# %%
import os
from datetime import datetime

from mltu.configs import BaseModelConfigs


class ModelConfigs(BaseModelConfigs):
    def __init__(self):
        super().__init__()
        self.model_path = os.path.join("Models/05_sound_to_text", datetime.strftime(datetime.now(), "%Y%m%d%H%M"))
        self.frame_length = 256
        self.frame_step = 160
        self.fft_length = 384

        self.vocab = "abcdefghijklmnopqrstuvwxyz "
        self.input_shape = None
        self.max_text_length = None
        self.max_spectrogram_length = None

        self.batch_size = 8
        self.learning_rate = 0.0005
        self.train_epochs = 1000
        self.train_workers = 20

# %%
import tensorflow as tf
from keras import layers
from keras.models import Model

from mltu.tensorflow.model_utils import residual_block, activation_layer


def train_model(input_dim, output_dim, activation="leaky_relu", dropout=0.2):

    inputs = layers.Input(shape=input_dim, name="input", dtype=tf.float32)

    # expand dims to add channel dimension
    input = layers.Lambda(lambda x: tf.expand_dims(x, axis=-1))(inputs)

    # Convolution layer 1
    x = layers.Conv2D(filters=32, kernel_size=[11, 41], strides=[2, 2], padding="same", use_bias=False)(input)
    x = layers.BatchNormalization()(x)
    x = activation_layer(x, activation="leaky_relu")

    # Convolution layer 2
    x = layers.Conv2D(filters=32, kernel_size=[11, 21], strides=[1, 2], padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = activation_layer(x, activation="leaky_relu")

    # Reshape the resulted volume to feed the RNNs layers
    x = layers.Reshape((-1, x.shape[-2] * x.shape[-1]))(x)

    # RNN layers
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)

    # Dense layer
    x = layers.Dense(256)(x)
    x = activation_layer(x, activation="leaky_relu")
    x = layers.Dropout(dropout)(x)

    # Classification layer
    output = layers.Dense(output_dim + 1, activation="softmax", dtype=tf.float32)(x)

    model = Model(inputs=inputs, outputs=output)
    return model

# %%
import tensorflow as tf


import os
import tarfile
import pandas as pd
from tqdm import tqdm
from urllib.request import urlopen
from io import BytesIO

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from mltu.preprocessors import WavReader

from mltu.tensorflow.dataProvider import DataProvider
from mltu.transformers import LabelIndexer, LabelPadding, SpectrogramPadding
from mltu.tensorflow.losses import CTCloss
from mltu.tensorflow.callbacks import Model2onnx, TrainLogger
from mltu.tensorflow.metrics import CERMetric, WERMetric

# %%
dataset_path = "/content/dataset"
metadata_path = dataset_path + "/metadata.csv"
wavs_path = dataset_path + "/waves/"

# Read metadata file and parse it
metadata_df = pd.read_csv(metadata_path, sep="|", header=None, quoting=3)
metadata_df.columns = ["file_name", "normalized_transcription"]
metadata_df = metadata_df[["file_name", "normalized_transcription"]]

# structure the dataset where each row is a list of [wav_file_path, sound transcription]
dataset = [[f"dataset/waves/{file}.wav", label.lower()] for file, label in metadata_df.values.tolist()]

# %%
dataset
# Out:
# [['dataset/waves/brbm9a.wav', 'bin red by m nine again'],
#  ['dataset/waves/pgay3a.wav', 'place green at y three again'],
#  ['dataset/waves/sbaa5s.wav', 'set blue at a five soon'],
#  ['dataset/waves/bbie9s.wav', 'bin blue in e nine soon'],
#  ['dataset/waves/pbib6n.wav', 'place blue in b six now'],
#  ['dataset/waves/swbi5s.wav', 'set white by i five soon'],
#  ['dataset/waves/srbizp.wav', 'set red by i zero please'],
#  ['dataset/waves/bwwuzn.wav', 'bin white with u zero now'],
#  ['dataset/waves/swbo9s.wav', 'set white by o nine soon'],
#  ['dataset/waves/pbwp9a.wav', 'place blue with p nine again'],
#  ['dataset/waves/lwbz4n.wav', 'lay white by z four now'],
#  ['dataset/waves/lgbm2n.wav', 'lay green by m two now'],
#  ['dataset/waves/lriq7s.wav', 'lay red in q seven soon'],
#  ['dataset/waves/lgil7a.wav', 'lay green in l seven again'],
#  ['dataset/waves/pgix7s.wav', 'place green in x seven soon'],
#  ['dataset/waves/srao1a.wav', 'set red at o one again'],
#  ['dataset/waves/srau2n.wav', 'set red at u two now'],
#  ['dataset/waves/pgay2p.wav', 'place green at y two please'],
#  ['dataset/waves/lbay1a.wav', 'lay blue at y one again'],
#  ['dataset/waves/sbig5s.wav', 'set blue in g five soon'],
#  ['dataset/waves/pbao8n.wav', 'place blue at o eight now'],
#  ['dataset/waves/lbbe1s.wav', 'lay blue by e one soon'],
#  ['dataset/waves/lbbe3a.wav', 'lay blue by e three again'],
#  ['dataset/waves/bbil3s.wav', 'bin blue in l three soon'],
#  ['dataset/waves/bbiz1s.wav', 'bin blue in z one soon'],
#  ['dataset/waves/swbi4n.wav', 'set white by i four now'],
#  ['dataset/waves/pripzn.wav', 'place red in p zero now'],
#  ['dataset/waves/pbbc7a.wav', 'place blue by c seven again'],
#  ['dataset/waves/swbp1a.wav', 'set white by p one again'],
#  ['dataset/waves/brwnzn.wav', 'bin red with n zero now'],
#  ['dataset/waves/srwo9a.wav', 'set red with o nine again'],
#  ['dataset/waves/pgaq8p.wav', 'place green at q eight please'],
#  ['dataset/waves/bbbs4n.wav', 'bin blue by s four now'],
#  ['dataset/waves/bwbhzp.wav', 'bin white by h zero please'],
#  ['dataset/waves/lgwg2n.wav', 'lay green with g two now'],
#  ['dataset/waves/lrblzn.wav', 'lay red by l zero now'],
#  ['dataset/waves/pbbp4p.wav', 'place blue by p four please'],
#  ['dataset/waves/pgby5s.wav', 'place green by y five soon'],
#  ['dataset/waves/pbbp2n.wav', 'place blue by p two now'],
#  ['dataset/waves/pwwk7a.wav', 'place white with k seven again'],
#  ['dataset/waves/sgii5a.wav', 'set green in i five again'],
#  ['dataset/waves/sgwj5s.wav', 'set green with j five soon'],
#  ['dataset/waves/brbg4p.wav', 'bin red by g four please'],
#  ['dataset/waves/sban4p.wav', 'set blue at n four please'],
#  ['dataset/waves/lwwm1s.wav', 'lay white with m one soon'],
#  ['dataset/waves/bbif1a.wav', 'bin blue in f one again'],
#  ['dataset/waves/sgbc6n.wav', 'set green by c six now'],
#  ['dataset/waves/lbby2n.wav', 'lay blue by y two now'],
#  ['dataset/waves/lwbf4p.wav', 'lay white by f four please'],
#  ['dataset/waves/brimzp.wav', 'bin red in m zero please'],
#  ['dataset/waves/prwq2n.wav', 'place red with q two now'],
#  ['dataset/waves/bbwm6p.wav', 'bin blue with m six please'],
#  ['dataset/waves/bbil4p.wav', 'bin blue in l four please'],
#  ['dataset/waves/lwie6p.wav', 'lay white in e six please'],
#  ['dataset/waves/lbwr5a.wav', 'lay blue with r five again'],
#  ['dataset/waves/pgak4p.wav', 'place green at k four please'],
#  ['dataset/waves/swbczn.wav', 'set white by c zero now'],
#  ['dataset/waves/sbim9s.wav', 'set blue in m nine soon'],
#  ['dataset/waves/lwar6n.wav', 'lay white at r six now'],
#  ['dataset/waves/lbad6n.wav', 'lay blue at d six now'],
#  ['dataset/waves/lrwl5s.wav', 'lay red sp with l five soon'],
#  ['dataset/waves/swih9a.wav', 'set white in h nine again'],
#  ['dataset/waves/srah7a.wav', 'set red at h seven again'],
#  ['dataset/waves/swbi7a.wav', 'set white by i seven again'],
#  ['dataset/waves/sbbh4p.wav', 'set blue by h four please'],
#  ['dataset/waves/bwag7a.wav', 'bin white at g seven again'],
#  ['dataset/waves/lgbf8n.wav', 'lay green by f eight now'],
#  ['dataset/waves/bgat8n.wav', 'bin green at t eight now'],
#  ['dataset/waves/pwwk6p.wav', 'place white with k six please'],
#  ['dataset/waves/bris5a.wav', 'bin red in s five again'],
#  ['dataset/waves/lbwr4p.wav', 'lay blue with r four please'],
#  ['dataset/waves/lrar2p.wav', 'lay red at r two please'],
#  ['dataset/waves/bris3s.wav', 'bin red in s three soon'],
#  ['dataset/waves/lwbs1s.wav', 'lay white by s one soon'],
#  ['dataset/waves/srbh9s.wav', 'set red by h nine soon'],
#  ['dataset/waves/lwbszn.wav', 'lay white by s zero now'],
#  ['dataset/waves/lbax8n.wav', 'lay blue at x eight now'],
#  ['dataset/waves/pbav5a.wav', 'place blue at v five again'],
#  ['dataset/waves/pbbv9a.wav', 'place blue by v nine again'],
#  ['dataset/waves/pwip7s.wav', 'place white in p seven soon'],
#  ['dataset/waves/sgac5a.wav', 'set green at c five again'],
#  ['dataset/waves/lgir9s.wav', 'lay green in r nine soon'],
#  ['dataset/waves/pgbk6n.wav', 'place green by k six now'],
#  ['dataset/waves/brwt6p.wav', 'bin red with t six please'],
#  ['dataset/waves/bgbu3s.wav', 'bin green by u three soon'],
#  ['dataset/waves/lrak8p.wav', 'lay red at k eight please'],
#  ['dataset/waves/lgaz8p.wav', 'lay green at z eight sp please'],
#  ['dataset/waves/prwx6n.wav', 'place red with x six now'],
#  ['dataset/waves/lrar3a.wav', 'lay red at r three again'],
#  ['dataset/waves/swiozn.wav', 'set white in o zero now'],
#  ['dataset/waves/bril9s.wav', 'bin red in l nine soon'],
#  ['dataset/waves/lgaz7s.wav', 'lay green at z seven soon'],
#  ['dataset/waves/srit9s.wav', 'set red in t nine soon'],
#  ['dataset/waves/praxzp.wav', 'place red at x zero please'],
#  ['dataset/waves/pwaq2p.wav', 'place white at q two please'],
#  ['dataset/waves/swwv6n.wav', 'set white with v six now'],
#  ['dataset/waves/pgbe2n.wav', 'place green by e two now'],
#  ['dataset/waves/lwbl6n.wav', 'lay white by l six now'],
#  ['dataset/waves/bbbz9s.wav', 'bin blue by z nine soon'],
#  ['dataset/waves/pwbkzn.wav', 'place white by k zero now'],
#  ['dataset/waves/pgby4n.wav', 'place green by y four now'],
#  ['dataset/waves/bbas1s.wav', 'bin blue at s one soon'],
#  ['dataset/waves/pbio5s.wav', 'place blue in o five soon'],
#  ['dataset/waves/lbbrzp.wav', 'lay blue by r zero please'],
#  ['dataset/waves/swao5s.wav', 'set white at o five soon'],
#  ['dataset/waves/pgwl3a.wav', 'place green with l three again'],
#  ['dataset/waves/pbiv1a.wav', 'place blue in v one again'],
#  ['dataset/waves/pbib7s.wav', 'place blue in b seven soon'],
#  ['dataset/waves/sbim8n.wav', 'set blue in m eight now'],
#  ['dataset/waves/pgwr5s.wav', 'place green with r five soon'],
#  ['dataset/waves/bgin3a.wav', 'bin green in n three again'],
#  ['dataset/waves/swab7s.wav', 'set white at b seven soon'],
#  ['dataset/waves/sgib9s.wav', 'set green in b nine soon'],
#  ['dataset/waves/sbat6n.wav', 'set blue at t six now'],
#  ['dataset/waves/brif7a.wav', 'bin red in f seven again'],
#  ['dataset/waves/prip1s.wav', 'place red in p one soon'],
#  ['dataset/waves/bgaa9a.wav', 'bin green at a nine again'],
#  ['dataset/waves/lgif1s.wav', 'lay green in f one soon'],
#  ['dataset/waves/lbwk9s.wav', 'lay blue with k nine soon'],
#  ['dataset/waves/swbi6p.wav', 'set white by i six please'],
#  ['dataset/waves/lwwf9a.wav', 'lay white with f nine again'],
#  ['dataset/waves/sgbx1a.wav', 'set green by x one again'],
#  ['dataset/waves/lrik5a.wav', 'lay red in k five again'],
#  ['dataset/waves/prwj8n.wav', 'place red with j eight now'],
#  ['dataset/waves/pgwe7s.wav', 'place green with e seven soon'],
#  ['dataset/waves/bgin1s.wav', 'bin green in n one soon'],
#  ['dataset/waves/bwbt8p.wav', 'bin white by t eight sp please'],
#  ['dataset/waves/lwie4n.wav', 'lay white sp in e four now'],
#  ['dataset/waves/pric4p.wav', 'place red in c four please'],
#  ['dataset/waves/pwwe2p.wav', 'place white with e two please'],
#  ['dataset/waves/prwd5s.wav', 'place red with d five soon'],
#  ['dataset/waves/lwiy8p.wav', 'lay white in y eight please'],
#  ['dataset/waves/pwwk4n.wav', 'place white with k four now'],
#  ['dataset/waves/sgwj7a.wav', 'set green with j seven again'],
#  ['dataset/waves/lbax9s.wav', 'lay blue at x nine soon'],
#  ['dataset/waves/brba1a.wav', 'bin red by a one again'],
#  ['dataset/waves/sbbbzp.wav', 'set blue by b zero please'],
#  ['dataset/waves/pgix8p.wav', 'place green in x eight please'],
#  ['dataset/waves/lwbz5s.wav', 'lay white sp by z five soon'],
#  ['dataset/waves/lwal3s.wav', 'lay white at l three soon'],
#  ['dataset/waves/swih8p.wav', 'set white in h eight please'],
#  ['dataset/waves/lgiz4p.wav', 'lay green in z four please'],
#  ['dataset/waves/prii8p.wav', 'place red in i eight please'],
#  ['dataset/waves/bgwh8n.wav', 'bin green with h eight now'],
#  ['dataset/waves/prwx8p.wav', 'place red with x eight please'],
#  ['dataset/waves/sran8n.wav', 'set red at n eight now'],
#  ['dataset/waves/bbil5a.wav', 'bin blue in l five again'],
#  ['dataset/waves/swbc3a.wav', 'set white by c three again'],
#  ['dataset/waves/prwq5a.wav', 'place red with q five again'],
#  ['dataset/waves/pgix6n.wav', 'place green in x six now'],
#  ['dataset/waves/sraozp.wav', 'set red at o zero please'],
#  ['dataset/waves/prav9s.wav', 'place red at v nine soon'],
#  ['dataset/waves/srwv3a.wav', 'set red with v three again'],
#  ['dataset/waves/lwaz2p.wav', 'lay white at z two please'],
#  ['dataset/waves/srab3a.wav', 'set red at b three again'],
#  ['dataset/waves/pwaj9a.wav', 'place white at j nine again'],
#  ['dataset/waves/sbba9s.wav', 'set blue by a nine soon'],
#  ['dataset/waves/sgio8p.wav', 'set green in o eight please'],
#  ['dataset/waves/swib2n.wav', 'set white in b two now'],
#  ['dataset/waves/pgayzn.wav', 'place green at y zero now'],
#  ['dataset/waves/pgwl1s.wav', 'place green with l one soon'],
#  ['dataset/waves/lrak7s.wav', 'lay red at k seven soon'],
#  ['dataset/waves/pbii1s.wav', 'place blue in i one soon'],
#  ['dataset/waves/bgbh5s.wav', 'bin green by h five soon'],
#  ['dataset/waves/lrae3s.wav', 'lay red at e three soon'],
#  ['dataset/waves/sbwo1s.wav', 'set blue with o one soon'],
#  ['dataset/waves/sgbc9a.wav', 'set green by c nine again'],
#  ['dataset/waves/praj3a.wav', 'place red at j three again'],
#  ['dataset/waves/bwig1s.wav', 'bin white in g one soon'],
#  ['dataset/waves/bbbs7a.wav', 'bin blue by s seven again'],
#  ['dataset/waves/bbaz5s.wav', 'bin blue at z five soon'],
#  ['dataset/waves/lrwszp.wav', 'lay red with s zero please'],
#  ['dataset/waves/lgaf7a.wav', 'lay green at f seven again'],
#  ['dataset/waves/lwae9s.wav', 'lay white at e nine soon'],
#  ['dataset/waves/bram5a.wav', 'bin red at m five again'],
#  ['dataset/waves/brwg9a.wav', 'bin red with g nine again'],
#  ['dataset/waves/lrbe8p.wav', 'lay red by e eight please'],
#  ['dataset/waves/sgai7s.wav', 'set green at i seven soon'],
#  ['dataset/waves/lgwm8p.wav', 'lay green with m eight please'],
#  ['dataset/waves/pbbjzp.wav', 'place blue by j zero please'],
#  ['dataset/waves/srit8n.wav', 'set red in t eight now'],
#  ['dataset/waves/bgbn8n.wav', 'bin green by n eight now'],
#  ['dataset/waves/bras8p.wav', 'bin red at s eight sp please'],
#  ['dataset/waves/pgbrzn.wav', 'place green by r zero now'],
#  ['dataset/waves/prbx5a.wav', 'place red by x five again'],
#  ['dataset/waves/pwbk3a.wav', 'place white by k three again'],
#  ['dataset/waves/pwidzp.wav', 'place white in d zero please'],
#  ['dataset/waves/srau4p.wav', 'set red at u four please'],
#  ['dataset/waves/brwg8p.wav', 'bin red with g eight please'],
#  ['dataset/waves/bbwtzp.wav', 'bin blue with t zero please'],
#  ['dataset/waves/bgia5a.wav', 'bin green in a five again'],
#  ['dataset/waves/bgan6p.wav', 'bin green at n six please'],
#  ['dataset/waves/sbwh9a.wav', 'set blue with h nine again'],
#  ['dataset/waves/prwj9s.wav', 'place red with j nine soon'],
#  ['dataset/waves/sgbp4n.wav', 'set green by p four now'],
#  ['dataset/waves/lwaz1s.wav', 'lay white at z one soon'],
#  ['dataset/waves/bwaa2p.wav', 'bin white at a two please'],
#  ['dataset/waves/lbby5a.wav', 'lay blue by y five again'],
#  ['dataset/waves/lbbq9s.wav', 'lay blue by q nine soon'],
#  ['dataset/waves/swih6n.wav', 'set white in h six now'],
#  ['dataset/waves/lgamzp.wav', 'lay green at m zero please'],
#  ['dataset/waves/lwiy7s.wav', 'lay white in y seven soon'],
#  ['dataset/waves/pwaj7s.wav', 'place white at j seven soon'],
#  ['dataset/waves/lrwr8n.wav', 'lay red with r eight now'],
#  ['dataset/waves/sbag8n.wav', 'set blue at g eight now'],
#  ['dataset/waves/brwa2n.wav', 'bin red with a two now'],
#  ['dataset/waves/lrae2n.wav', 'lay red at e two now'],
#  ['dataset/waves/pbwc9s.wav', 'place blue with c nine soon'],
#  ['dataset/waves/lwwf8p.wav', 'lay white with f eight please'],
#  ['dataset/waves/lbiq1s.wav', 'lay blue in q one soon'],
#  ['dataset/waves/srbu7s.wav', 'set red by u seven soon'],
#  ['dataset/waves/lwir2n.wav', 'lay white in r two now'],
#  ['dataset/waves/swio2p.wav', 'set white in o two please'],
#  ['dataset/waves/lbaq4n.wav', 'lay blue at q four now'],
#  ['dataset/waves/lbaq5s.wav', 'lay blue sp at q five soon'],
#  ['dataset/waves/pwix1s.wav', 'place white in x one soon'],
#  ['dataset/waves/lrbe6n.wav', 'lay red by e six now'],
#  ['dataset/waves/lgbm3s.wav', 'lay green by m three soon'],
#  ['dataset/waves/lwar9a.wav', 'lay white at r nine again'],
#  ['dataset/waves/pgad8n.wav', 'place green at d eight now'],
#  ['dataset/waves/pgikzp.wav', 'place green in k zero please'],
#  ['dataset/waves/brwg7s.wav', 'bin red with g seven soon'],
#  ['dataset/waves/sgwqzp.wav', 'set green with q zero please'],
#  ['dataset/waves/lwir3s.wav', 'lay white in r three soon'],
#  ['dataset/waves/lbix6p.wav', 'lay blue in x six please'],
#  ['dataset/waves/srwv2p.wav', 'set red with v two please'],
#  ['dataset/waves/lbid2n.wav', 'lay blue in d two now'],
#  ['dataset/waves/srwczp.wav', 'set red with c zero please'],
#  ['dataset/waves/lgil4n.wav', 'lay green in l four now'],
#  ['dataset/waves/pbbi9s.wav', 'place blue by i nine soon'],
#  ['dataset/waves/lwal5a.wav', 'lay white at l five again'],
#  ['dataset/waves/sgwd2p.wav', 'set green with d two please'],
#  ['dataset/waves/bgbh6p.wav', 'bin green by h six please'],
#  ['dataset/waves/srwb8n.wav', 'set red with b eight now'],
#  ['dataset/waves/pwip9a.wav', 'place white in p nine again'],
#  ['dataset/waves/pgbe4p.wav', 'place green by e four please'],
#  ['dataset/waves/swai3a.wav', 'set white at i three again'],
#  ['dataset/waves/pbapzp.wav', 'place blue at p zero please'],
#  ['dataset/waves/srbu8p.wav', 'set red by u eight please'],
#  ['dataset/waves/bwbt9a.wav', 'bin white by t nine again'],
#  ['dataset/waves/lrae4p.wav', 'lay red at e four please'],
#  ['dataset/waves/lray7a.wav', 'lay red at y seven again'],
#  ['dataset/waves/bwwh3s.wav', 'bin white with h three soon'],
#  ['dataset/waves/bwag6p.wav', 'bin white at g six please'],
#  ['dataset/waves/lray4n.wav', 'lay red at y four now'],
#  ['dataset/waves/pgwr7a.wav', 'place green with r seven again'],
#  ['dataset/waves/swwc4n.wav', 'set white with c four now'],
#  ['dataset/waves/pbbv7s.wav', 'place blue by v seven soon'],
#  ['dataset/waves/swwv9a.wav', 'set white with sp v nine again'],
#  ['dataset/waves/lrak6n.wav', 'lay red at k six now'],
#  ['dataset/waves/bbiz2p.wav', 'bin blue in z sp two please'],
#  ['dataset/waves/brbt3a.wav', 'bin red by t three again'],
#  ['dataset/waves/lbwe7a.wav', 'lay blue with e seven again'],
#  ['dataset/waves/pgwr6p.wav', 'place green with r six please'],
#  ['dataset/waves/lbid4p.wav', 'lay blue in d four please'],
#  ['dataset/waves/bwat4p.wav', 'bin white at t four please'],
#  ['dataset/waves/sbat7s.wav', 'set blue at t seven soon'],
#  ['dataset/waves/priv5s.wav', 'place red in v five soon'],
#  ['dataset/waves/pgaq9a.wav', 'place green at q nine again'],
#  ['dataset/waves/bwwa9s.wav', 'bin white with a nine soon'],
#  ['dataset/waves/pbiu9s.wav', 'place blue in u nine soon'],
#  ['dataset/waves/sbbn6n.wav', 'set blue by n six now'],
#  ['dataset/waves/lbwy9a.wav', 'lay blue with y nine again'],
#  ['dataset/waves/srabzn.wav', 'set red at b zero now'],
#  ['dataset/waves/pwbq5s.wav', 'place white by q five soon'],
#  ['dataset/waves/lgbm5a.wav', 'lay green by m five again'],
#  ['dataset/waves/pric3s.wav', 'place red in c three soon'],
#  ['dataset/waves/lbak3a.wav', 'lay blue at k three again'],
#  ['dataset/waves/bgbb3a.wav', 'bin green by b three again'],
#  ['dataset/waves/bbwg3a.wav', 'bin blue with g three again'],
#  ['dataset/waves/bgwb5s.wav', 'bin green with b five soon'],
#  ['dataset/waves/srih3a.wav', 'set red in h three again'],
#  ['dataset/waves/pbbv6n.wav', 'place blue by v six now'],
#  ['dataset/waves/pgak2n.wav', 'place green at k two now'],
#  ['dataset/waves/prip3a.wav', 'place red in p three again'],
#  ['dataset/waves/pwwq9s.wav', 'place white with q nine soon'],
#  ['dataset/waves/lgir8n.wav', 'lay green in r eight now'],
#  ['dataset/waves/brbg3s.wav', 'bin red by g three soon'],
#  ['dataset/waves/lrwf2p.wav', 'lay red with f two please'],
#  ['dataset/waves/lriy2p.wav', 'lay red in y two please'],
#  ['dataset/waves/bbal9a.wav', 'bin blue at l nine again'],
#  ['dataset/waves/lbbr1a.wav', 'lay blue by r one again'],
#  ['dataset/waves/srin7a.wav', 'set red in n seven again'],
#  ['dataset/waves/lrie1a.wav', 'lay red in e one again'],
#  ['dataset/waves/prac8p.wav', 'place red at c eight please'],
#  ['dataset/waves/bbbm2p.wav', 'bin blue by m two please'],
#  ['dataset/waves/pwad4p.wav', 'place white at d four please'],
#  ['dataset/waves/prwd7a.wav', 'place red with d seven again'],
#  ['dataset/waves/lgaf6p.wav', 'lay green at f six please'],
#  ['dataset/waves/pgby7a.wav', 'place green by y seven again'],
#  ['dataset/waves/bbir7s.wav', 'bin blue in r seven soon'],
#  ['dataset/waves/pwaq3a.wav', 'place white at q three again'],
#  ['dataset/waves/bgah1s.wav', 'bin green at h one soon'],
#  ['dataset/waves/srin4n.wav', 'set red in n four now'],
#  ['dataset/waves/pgaq7s.wav', 'place green at q seven soon'],
#  ['dataset/waves/pwax5s.wav', 'place white at x five soon'],
#  ['dataset/waves/lriezp.wav', 'lay red in e zero please'],
#  ['dataset/waves/sgbp5s.wav', 'set green by p five soon'],
#  ['dataset/waves/lwafzp.wav', 'lay white at f zero please'],
#  ['dataset/waves/brbm7s.wav', 'bin red by m seven soon'],
#  ['dataset/waves/prav8n.wav', 'place red at v eight now'],
#  ['dataset/waves/lgwm7s.wav', 'lay green with m seven soon'],
#  ['dataset/waves/pgix9a.wav', 'place green in x nine again'],
#  ['dataset/waves/bgbbzn.wav', 'bin green by b zero now'],
#  ['dataset/waves/pgiq2n.wav', 'place green in q two now'],
#  ['dataset/waves/bwit1a.wav', 'bin white in t one again'],
#  ['dataset/waves/lrbr5s.wav', 'lay red by r five soon'],
#  ['dataset/waves/pgwzzp.wav', 'place green with z zero please'],
#  ['dataset/waves/bwan1a.wav', 'bin white at n one again'],
#  ['dataset/waves/lrik3s.wav', 'lay red in k three soon'],
#  ['dataset/waves/bwwn7s.wav', 'bin white with n seven soon'],
#  ['dataset/waves/sgbjzn.wav', 'set green by j zero now'],
#  ['dataset/waves/sgbxzp.wav', 'set green by x zero please'],
#  ['dataset/waves/sgai9a.wav', 'set green at i nine again'],
#  ['dataset/waves/lwiy6n.wav', 'lay white in y six now'],
#  ['dataset/waves/swwc6p.wav', 'set white with c six please'],
#  ['dataset/waves/prbj4n.wav', 'place red by j four now'],
#  ['dataset/waves/srab1s.wav', 'set red at b one soon'],
#  ['dataset/waves/pbbv8p.wav', 'place blue by v eight please'],
#  ['dataset/waves/lrwz3s.wav', 'lay red with z three soon'],
#  ['dataset/waves/pbiizn.wav', 'place blue in i zero now'],
#  ['dataset/waves/pgaq6n.wav', 'place green at q six now'],
#  ['dataset/waves/prip2p.wav', 'place red in p two please'],
#  ['dataset/waves/bgwo4p.wav', 'bin green with o four please'],
#  ['dataset/waves/prbdzn.wav', 'place red by d zero now'],
#  ['dataset/waves/swib4p.wav', 'set white in b four please'],
#  ['dataset/waves/bwbn2n.wav', 'bin white by n two now'],
#  ['dataset/waves/pbib8p.wav', 'place blue in b eight please'],
#  ['dataset/waves/lwazzn.wav', 'lay white at z zero now'],
#  ['dataset/waves/swio1s.wav', 'set white in o one soon'],
#  ['dataset/waves/lbbk6p.wav', 'lay blue by k six please'],
#  ['dataset/waves/srwi3s.wav', 'set red with i three soon'],
#  ['dataset/waves/bbbm1s.wav', 'bin blue by m one soon'],
#  ['dataset/waves/srbo4p.wav', 'set red by o four please'],
#  ['dataset/waves/bbal6n.wav', 'bin blue at l six now'],
#  ['dataset/waves/bgwb4n.wav', 'bin green with b four now'],
#  ['dataset/waves/bgig9a.wav', 'bin green in g nine again'],
#  ['dataset/waves/lwwf6n.wav', 'lay white with f six now'],
#  ['dataset/waves/bgah3a.wav', 'bin green at h three again'],
#  ['dataset/waves/bgbo1a.wav', 'bin green by o one again'],
#  ['dataset/waves/swbc2p.wav', 'set white by c two please'],
#  ['dataset/waves/srbo3s.wav', 'set red by o three soon'],
#  ['dataset/waves/bgwizp.wav', 'bin green with i zero please'],
#  ['dataset/waves/lbid5a.wav', 'lay blue in d five again'],
#  ['dataset/waves/srbu6n.wav', 'set red by u six now'],
#  ['dataset/waves/lgbm4p.wav', 'lay green by m four please'],
#  ['dataset/waves/lrae5a.wav', 'lay red at e five again'],
#  ['dataset/waves/pgbe5a.wav', 'place green by e five again'],
#  ['dataset/waves/prbq1a.wav', 'place red by q one again'],
#  ['dataset/waves/bbir9a.wav', 'bin blue in r nine again'],
#  ['dataset/waves/prii9a.wav', 'place red in i nine again'],
#  ['dataset/waves/prac9a.wav', 'place red at c nine again'],
#  ['dataset/waves/lbij6n.wav', 'lay blue in j six now'],
#  ['dataset/waves/lriy1s.wav', 'lay red in y one soon'],
#  ['dataset/waves/lbwr2n.wav', 'lay blue with r two now'],
#  ['dataset/waves/swbv5a.wav', 'set white by v five again'],
#  ['dataset/waves/lgwt3a.wav', 'lay green with t three again'],
#  ['dataset/waves/pric5a.wav', 'place red in c five again'],
#  ['dataset/waves/srih2p.wav', 'set red in h two please'],
#  ['dataset/waves/lwar7s.wav', 'lay white at r seven soon'],
#  ['dataset/waves/bbbf7s.wav', 'bin blue by f seven soon'],
#  ['dataset/waves/bgwo5a.wav', 'bin green with o five again'],
#  ['dataset/waves/lbby3s.wav', 'lay blue by y three soon'],
#  ['dataset/waves/prbj7a.wav', 'place red by j seven again'],
#  ['dataset/waves/pgwy9s.wav', 'place green with y nine soon'],
#  ['dataset/waves/lgiszp.wav', 'lay green in s zero please'],
#  ['dataset/waves/lbad8p.wav', 'lay blue at d eight please'],
#  ['dataset/waves/briz8p.wav', 'bin red in z eight please'],
#  ['dataset/waves/lgifzn.wav', 'lay green in f zero now'],
#  ['dataset/waves/lrid8n.wav', 'lay red in d eight now'],
#  ['dataset/waves/bgaa7s.wav', 'bin green at a seven soon'],
#  ['dataset/waves/bbaf5a.wav', 'bin blue at f five again'],
#  ['dataset/waves/srbb7a.wav', 'set red by b seven again'],
#  ['dataset/waves/pgaezp.wav', 'place green at e zero please'],
#  ['dataset/waves/lbwy8p.wav', 'lay blue with y eight please'],
#  ['dataset/waves/lbbk4n.wav', 'lay blue by k four now'],
#  ['dataset/waves/brbm6n.wav', 'bin red by m six now'],
#  ['dataset/waves/priv4n.wav', 'place red in v four now'],
#  ['dataset/waves/lrarzn.wav', 'lay red at r zero now'],
#  ['dataset/waves/bgit7a.wav', 'bin green in t seven again'],
#  ['dataset/waves/bgwo3s.wav', 'bin green with o three soon'],
#  ['dataset/waves/sbwb2n.wav', 'set blue with b two now'],
#  ['dataset/waves/pwix3a.wav', 'place white in x three again'],
#  ['dataset/waves/swiu6p.wav', 'set white in u six please'],
#  ['dataset/waves/pgae1a.wav', 'place green at e one again'],
#  ['dataset/waves/pwixzn.wav', 'place white in x zero now'],
#  ['dataset/waves/sbwb5a.wav', 'set blue with b five again'],
#  ['dataset/waves/pgay1s.wav', 'place green at y one soon'],
#  ['dataset/waves/lwbf2n.wav', 'lay white by f two now'],
#  ['dataset/waves/lwie5s.wav', 'lay white in e five soon'],
#  ['dataset/waves/bgig6n.wav', 'bin green in g six now'],
#  ['dataset/waves/pwbx9s.wav', 'place white by x nine soon'],
#  ['dataset/waves/sgwx4p.wav', 'set green with x four please'],
#  ['dataset/waves/brbg2n.wav', 'bin red sp by g two now'],
#  ['dataset/waves/lbwe5s.wav', 'lay blue with e five soon'],
#  ['dataset/waves/lrwz4p.wav', 'lay red with z four please'],
#  ['dataset/waves/lrwz2n.wav', 'lay red with z sp two now'],
#  ['dataset/waves/bbiz3a.wav', 'bin blue in z three again'],
#  ['dataset/waves/lgil6p.wav', 'lay green in l six please'],
#  ['dataset/waves/bras9a.wav', 'bin red at s nine again'],
#  ['dataset/waves/sgio9a.wav', 'set green in o nine again'],
#  ['dataset/waves/bgbb2p.wav', 'bin green by b two please'],
#  ['dataset/waves/sgav4n.wav', 'set green at v four now'],
#  ['dataset/waves/swab9a.wav', 'set white at b nine again'],
#  ['dataset/waves/pwby1a.wav', 'place white by y one again'],
#  ['dataset/waves/pbwx2p.wav', 'place blue with x two please'],
#  ['dataset/waves/pwad2n.wav', 'place white at d two now'],
#  ['dataset/waves/pbwp8p.wav', 'place blue with p eight please'],
#  ['dataset/waves/pwwr1a.wav', 'place white with r one again'],
#  ['dataset/waves/prwd4n.wav', 'place red with d four now'],
#  ['dataset/waves/swiu5s.wav', 'set white in u five soon'],
#  ['dataset/waves/bbbmzn.wav', 'bin blue by m zero now'],
#  ['dataset/waves/lrbr6p.wav', 'lay red by r six please'],
#  ['dataset/waves/sgwx3s.wav', 'set green with x three soon'],
#  ['dataset/waves/sban3s.wav', 'set blue at n three soon'],
#  ['dataset/waves/srbu9a.wav', 'set red by u nine again'],
#  ['dataset/waves/sbwh8p.wav', 'set blue with h eight please'],
#  ['dataset/waves/prwq4p.wav', 'place red with q four please'],
#  ['dataset/waves/swbpzp.wav', 'set white by p zero please'],
#  ['dataset/waves/sbbb1a.wav', 'set blue by b one again'],
#  ['dataset/waves/pgiq4p.wav', 'place green in q four please'],
#  ['dataset/waves/bbir6n.wav', 'bin blue in r six now'],
#  ['dataset/waves/pbwj5a.wav', 'place blue with j five again'],
#  ['dataset/waves/lgwazp.wav', 'lay green with a zero please'],
#  ['dataset/waves/sgbc7s.wav', 'set green by c seven soon'],
#  ['dataset/waves/pgby6p.wav', 'place green by y six please'],
#  ['dataset/waves/pwwe3a.wav', 'place white with e three again'],
#  ['dataset/waves/lbakzn.wav', 'lay blue at k zero now'],
#  ['dataset/waves/srah5s.wav', 'set red at h five soon'],
#  ['dataset/waves/prwq3s.wav', 'place red with q three soon'],
#  ['dataset/waves/sgwx5a.wav', 'set green with x five again'],
#  ['dataset/waves/pwip6n.wav', 'place white in p six now'],
#  ['dataset/waves/bwaa3a.wav', 'bin white at a three again'],
#  ['dataset/waves/prap5s.wav', 'place red at p five soon'],
#  ['dataset/waves/sbwu7a.wav', 'set blue with u seven again'],
#  ['dataset/waves/bbaz4n.wav', 'bin blue at z four now'],
#  ['dataset/waves/lbbk5s.wav', 'lay blue by k five soon'],
#  ['dataset/waves/pwij2n.wav', 'place white in j two now'],
#  ['dataset/waves/bgan5s.wav', 'bin green at n five soon'],
#  ['dataset/waves/srau3s.wav', 'set red at u three soon'],
#  ['dataset/waves/pwbd7s.wav', 'place white by d seven soon'],
#  ['dataset/waves/brbm8p.wav', 'bin red by m eight please'],
#  ['dataset/waves/sbbu1s.wav', 'set blue by u one soon'],
#  ['dataset/waves/sgapzn.wav', 'set green at p zero now'],
#  ['dataset/waves/lgwm6n.wav', 'lay green with m six now'],
#  ['dataset/waves/lrwfzn.wav', 'lay red with f zero now'],
#  ['dataset/waves/lwwf7s.wav', 'lay white with f seven soon'],
#  ['dataset/waves/sbbu2p.wav', 'set blue by u two please'],
#  ['dataset/waves/lbwl1a.wav', 'lay blue with l one again'],
#  ['dataset/waves/swib3s.wav', 'set white in b three soon'],
#  ['dataset/waves/bgbu2n.wav', 'bin green by u two now'],
#  ['dataset/waves/brwn2p.wav', 'bin red with n two please'],
#  ['dataset/waves/pwwezn.wav', 'place white with e zero now'],
#  ['dataset/waves/lwws6p.wav', 'lay white with s six please'],
#  ['dataset/waves/brbazp.wav', 'bin red by a zero please'],
#  ['dataset/waves/swih7s.wav', 'set white in h seven soon'],
#  ['dataset/waves/bbwg1s.wav', 'bin blue with g one soon'],
#  ['dataset/waves/sban5a.wav', 'set blue at n five again'],
#  ['dataset/waves/bbal8p.wav', 'bin blue at l eight please'],
#  ['dataset/waves/lwwm2p.wav', 'lay white with m two please'],
#  ['dataset/waves/bgwh9s.wav', 'bin green with h nine soon'],
#  ['dataset/waves/swwv7s.wav', 'set white with v seven soon'],
#  ['dataset/waves/lgwg4p.wav', 'lay green with g four please'],
#  ['dataset/waves/bbaz6p.wav', 'bin blue at z six please'],
#  ['dataset/waves/pgid7a.wav', 'place green in d seven again'],
#  ['dataset/waves/lwbf5a.wav', 'lay white by f five again'],
#  ['dataset/waves/prbx4p.wav', 'place red by x four please'],
#  ['dataset/waves/sbwh7s.wav', 'set blue with h seven soon'],
#  ['dataset/waves/bbwg2p.wav', 'bin blue with g two please'],
#  ['dataset/waves/lwir4p.wav', 'lay white in r four please'],
#  ['dataset/waves/lwaz3a.wav', 'lay white at z three again'],
#  ['dataset/waves/bgia2n.wav', 'bin green in a two now'],
#  ['dataset/waves/lriyzn.wav', 'lay red in y zero now'],
#  ['dataset/waves/pwbk1s.wav', 'place white by k one soon'],
#  ['dataset/waves/prbx3s.wav', 'place red by x three soon'],
#  ['dataset/waves/swai1s.wav', 'set white at i one soon'],
#  ['dataset/waves/sgap1s.wav', 'set green at p one soon'],
#  ['dataset/waves/brwn3a.wav', 'bin red with n three again'],
#  ['dataset/waves/pbii2p.wav', 'place blue in i two please'],
#  ['dataset/waves/lgbf9s.wav', 'lay green by f nine soon'],
#  ['dataset/waves/pwix2p.wav', 'place white in x two please'],
#  ['dataset/waves/prac7s.wav', 'place red at c seven soon'],
#  ['dataset/waves/sbin1a.wav', 'set blue in n one again'],
#  ['dataset/waves/prbp9s.wav', 'place red by p nine soon'],
#  ['dataset/waves/pgid4n.wav', 'place green in d four now'],
#  ['dataset/waves/lrik4p.wav', 'lay red in k four please'],
#  ['dataset/waves/pric2n.wav', 'place red in c two now'],
#  ['dataset/waves/brif6p.wav', 'bin red in f six please'],
#  ['dataset/waves/pwij4p.wav', 'place white in j four please'],
#  ['dataset/waves/sbit5a.wav', 'set blue in t five again'],
#  ['dataset/waves/sbwb3s.wav', 'set sp blue with b three soon'],
#  ['dataset/waves/pwax6p.wav', 'place white at x six please'],
#  ['dataset/waves/pbac3a.wav', 'place blue at c three again'],
#  ['dataset/waves/pbwp7s.wav', 'place blue with p seven soon'],
#  ['dataset/waves/prii7s.wav', 'place red in i seven soon'],
#  ['dataset/waves/sbwo2p.wav', 'set blue with o two please'],
#  ['dataset/waves/pbwc8n.wav', 'place blue with c eight now'],
#  ['dataset/waves/sbahzp.wav', 'set blue at h zero please'],
#  ['dataset/waves/pbwd1a.wav', 'place blue with d one again'],
#  ['dataset/waves/lbiqzn.wav', 'lay blue in q zero now'],
#  ['dataset/waves/swav1a.wav', 'set white at v one again'],
#  ['dataset/waves/bgwi1a.wav', 'bin green with i one again'],
#  ['dataset/waves/brwn1s.wav', 'bin red with n one soon'],
#  ['dataset/waves/bgbu5a.wav', 'bin green by u five again'],
#  ['dataset/waves/bgaa6n.wav', 'bin green at a six now'],
#  ['dataset/waves/lbwe4n.wav', 'lay blue with e four now'],
#  ['dataset/waves/pgwr4n.wav', 'place green with r four now'],
#  ['dataset/waves/brif4n.wav', 'bin red in f four now'],
#  ['dataset/waves/pgwl2p.wav', 'place green with l two please'],
#  ['dataset/waves/bbaf4p.wav', 'bin blue at f four please'],
#  ['dataset/waves/pbwx1s.wav', 'place blue with x one soon'],
#  ['dataset/waves/lrwf1s.wav', 'lay red with f one soon'],
#  ['dataset/waves/lrbe9a.wav', 'lay red by e nine again'],
#  ['dataset/waves/lgbs7s.wav', 'lay green by s seven soon'],
#  ['dataset/waves/brim1a.wav', 'bin red in m one again'],
#  ['dataset/waves/srbb4n.wav', 'set red by b four now'],
#  ['dataset/waves/bwanzp.wav', 'bin white at n zero please'],
#  ['dataset/waves/sgap3a.wav', 'set green at p three again'],
#  ['dataset/waves/sgwj4n.wav', 'set green with j four now'],
#  ['dataset/waves/bwwh4p.wav', 'bin white with h four please'],
#  ['dataset/waves/pbwx3a.wav', 'place blue with x three again'],
#  ['dataset/waves/bgauzp.wav', 'bin green at u zero please'],
#  ['dataset/waves/bgit5s.wav', 'bin green in t five soon'],
#  ['dataset/waves/pbav2n.wav', 'place blue at v two now'],
#  ['dataset/waves/sbinzp.wav', 'set blue in n zero please'],
#  ['dataset/waves/sgwq1a.wav', 'set green with q one again'],
#  ['dataset/waves/bgwu8p.wav', 'bin green with u eight please'],
#  ['dataset/waves/swau9s.wav', 'set white at u nine soon'],
#  ['dataset/waves/bgit4n.wav', 'bin green in t four now'],
#  ['dataset/waves/pgik1a.wav', 'place green in k one again'],
#  ['dataset/waves/bgbb1s.wav', 'bin green by b one soon'],
#  ['dataset/waves/prwd6p.wav', 'place red with d six please'],
#  ['dataset/waves/lbbe2p.wav', 'lay blue by e two please'],
#  ['dataset/waves/lbak2p.wav', 'lay blue at k two please'],
#  ['dataset/waves/pgwz1a.wav', 'place green with z one again'],
#  ['dataset/waves/bgwb7a.wav', 'bin green with b seven again'],
#  ['dataset/waves/bbwt1a.wav', 'bin blue with t one again'],
#  ['dataset/waves/lwal4p.wav', 'lay white at l four please'],
#  ['dataset/waves/lwwmzn.wav', 'lay white with m zero now'],
#  ['dataset/waves/bbizzn.wav', 'bin blue in z zero now'],
#  ['dataset/waves/sbbn7s.wav', 'set blue by n seven soon'],
#  ['dataset/waves/bbwm7a.wav', 'bin blue with m seven again'],
#  ['dataset/waves/bwbg9s.wav', 'bin white by g nine soon'],
#  ['dataset/waves/sria7s.wav', 'set red in a seven soon'],
#  ['dataset/waves/sgav5s.wav', 'set green at v five soon'],
#  ['dataset/waves/sbah1a.wav', 'set blue at h one again'],
#  ['dataset/waves/bbwm4n.wav', 'bin blue with m four now'],
#  ['dataset/waves/sbbh3s.wav', 'set blue by h three soon'],
#  ['dataset/waves/lgam1a.wav', 'lay green at m one again'],
#  ['dataset/waves/bgig7s.wav', 'bin green in g seven soon'],
#  ['dataset/waves/lbwy6n.wav', 'lay blue with y six now'],
#  ['dataset/waves/pgij8n.wav', 'place green in j eight now'],
#  ['dataset/waves/lrby8n.wav', 'lay red by y eight now'],
#  ['dataset/waves/bwim5s.wav', 'bin white in m five soon'],
#  ['dataset/waves/bgbu4p.wav', 'bin green by u four please'],
#  ['dataset/waves/lgwa1a.wav', 'lay green with a one again'],
#  ['dataset/waves/bwbg8n.wav', 'bin white by g eight now'],
#  ['dataset/waves/pbii3a.wav', 'place blue in i three again'],
#  ['dataset/waves/brwt7a.wav', 'bin red with t seven again'],
#  ['dataset/waves/bwwh5a.wav', 'bin white with h five again'],
#  ['dataset/waves/swwv8p.wav', 'set white with v eight please'],
#  ['dataset/waves/pgwlzn.wav', 'place green with l zero now'],
#  ['dataset/waves/bgwu6n.wav', 'bin green with u six now'],
#  ['dataset/waves/bgbh7a.wav', 'bin green by h seven again'],
#  ['dataset/waves/bbifzp.wav', 'bin blue in f zero please'],
#  ['dataset/waves/sbbn8p.wav', 'set blue by n eight sp please'],
#  ['dataset/waves/bbir8p.wav', 'bin blue in r eight please'],
#  ['dataset/waves/sbwh6n.wav', 'set blue with h six now'],
#  ['dataset/waves/bwwh2n.wav', 'bin white with h two now'],
#  ['dataset/waves/bwis9s.wav', 'bin white in s nine soon'],
#  ['dataset/waves/lbiq2p.wav', 'lay blue in q two please'],
#  ['dataset/waves/lgiz2n.wav', 'lay green in z two now'],
#  ['dataset/waves/pgbr2p.wav', 'place green by r two please'],
#  ['dataset/waves/lbad9a.wav', 'lay blue at d nine again'],
#  ['dataset/waves/sgwdzn.wav', 'set green with d zero now'],
#  ['dataset/waves/prap7a.wav', 'place red at sp p seven again'],
#  ['dataset/waves/prbqzp.wav', 'place red by q zero please'],
#  ['dataset/waves/lriq6n.wav', 'lay red in q six now'],
#  ['dataset/waves/pwwy3s.wav', 'place white with y three soon'],
#  ['dataset/waves/brwg6n.wav', 'bin red with g six now'],
#  ['dataset/waves/sbwu6p.wav', 'set blue with u six please'],
#  ['dataset/waves/lwwm3a.wav', 'lay white with m three again'],
#  ['dataset/waves/pwic9s.wav', 'place white in c nine soon'],
#  ['dataset/waves/prii6n.wav', 'place red in i six now'],
#  ['dataset/waves/bris2n.wav', 'bin red in s two now'],
#  ['dataset/waves/lwal2n.wav', 'lay white at l two now'],
#  ['dataset/waves/brbtzn.wav', 'bin red by t zero now'],
#  ['dataset/waves/pwaj8p.wav', 'place white at j eight please'],
#  ['dataset/waves/sgac2n.wav', 'set green at c two now'],
#  ['dataset/waves/bwat5a.wav', 'bin white at t five again'],
#  ['dataset/waves/sran9s.wav', 'set red at n nine soon'],
#  ['dataset/waves/swab8p.wav', 'set white at b eight please'],
#  ['dataset/waves/sria9a.wav', 'set red in a nine again'],
#  ['dataset/waves/prap6p.wav', 'place red at sp p six please'],
#  ['dataset/waves/lrbl1s.wav', 'lay red by l one soon'],
#  ['dataset/waves/pbap1a.wav', 'place blue at p one again'],
#  ['dataset/waves/swavzp.wav', 'set white at v zero please'],
#  ['dataset/waves/lray5s.wav', 'lay red at y five soon'],
#  ['dataset/waves/bril8n.wav', 'bin red in l eight now'],
#  ['dataset/waves/lrwl6p.wav', 'lay red with l six please'],
#  ['dataset/waves/pgwe8p.wav', 'place green with e eight please'],
#  ['dataset/waves/lrwl7a.wav', 'lay red with l seven again'],
#  ['dataset/waves/srwo6n.wav', 'set red with o six now'],
#  ['dataset/waves/bwitzp.wav', 'bin white in t zero please'],
#  ['dataset/waves/lgbs6n.wav', 'lay green by s six now'],
#  ['dataset/waves/lbij8p.wav', 'lay blue in j eight please'],
#  ['dataset/waves/pgad9s.wav', 'place green at d nine soon'],
#  ['dataset/waves/prbj5s.wav', 'place red by j five soon'],
#  ['dataset/waves/swwi8n.wav', 'set white with i eight now'],
#  ['dataset/waves/srbo2n.wav', 'set red by o two now'],
#  ['dataset/waves/bbie8n.wav', 'bin blue in e eight now'],
#  ['dataset/waves/prap4n.wav', 'place red at p four now'],
#  ['dataset/waves/bgia4p.wav', 'bin green in a four please'],
#  ['dataset/waves/bwba7a.wav', 'bin white by a seven again'],
#  ['dataset/waves/swai2p.wav', 'set white at i two please'],
#  ['dataset/waves/pbwj3s.wav', 'place blue with j three soon'],
#  ['dataset/waves/bwwn6n.wav', 'bin white sp with n six now'],
#  ['dataset/waves/pbac2p.wav', 'place blue at c two please'],
#  ['dataset/waves/bbaf3s.wav', 'bin blue at f three soon'],
#  ['dataset/waves/bgwu7s.wav', 'bin green with u seven soon'],
#  ['dataset/waves/bgbh4n.wav', 'bin green by h four now'],
#  ['dataset/waves/sgbv9s.wav', 'set green by v nine soon'],
#  ['dataset/waves/lbij9a.wav', 'lay blue in j nine again'],
#  ['dataset/waves/brwt4n.wav', 'bin red with t four now'],
#  ['dataset/waves/bwwn9a.wav', 'bin white with n nine again'],
#  ['dataset/waves/srwvzn.wav', 'set red with v zero now'],
#  ['dataset/waves/srwv1s.wav', 'set red with v one soon'],
#  ['dataset/waves/pbav3s.wav', 'place blue at v three soon'],
#  ['dataset/waves/pgiq5a.wav', 'place green in q five again'],
#  ['dataset/waves/pgbr3a.wav', 'place green by r three again'],
#  ['dataset/waves/bwwbzp.wav', 'bin white with b zero please'],
#  ['dataset/waves/bwaa1s.wav', 'bin white at a one soon'],
#  ['dataset/waves/sbig6p.wav', 'set blue in g six please'],
#  ['dataset/waves/lrby9s.wav', 'lay red by y nine soon'],
#  ['dataset/waves/prwk1a.wav', 'place red with k one again'],
#  ['dataset/waves/sgbv8n.wav', 'set green by v eight now'],
#  ['dataset/waves/pbivzp.wav', 'place blue in v zero please'],
#  ['dataset/waves/swwp2n.wav', 'set white with p two now'],
#  ['dataset/waves/sgwx2n.wav', 'set green with x two now'],
#  ['dataset/waves/swwp4p.wav', 'set white with p four please'],
#  ['dataset/waves/pgwe6n.wav', 'place green with e six now'],
#  ['dataset/waves/pwwrzp.wav', 'place white with r zero please'],
#  ['dataset/waves/lwbl8p.wav', 'lay white sp by l eight please'],
#  ['dataset/waves/swwc5s.wav', 'set white with c five soon'],
#  ['dataset/waves/lrbe7s.wav', 'lay red by e seven soon'],
#  ['dataset/waves/bwwa8n.wav', 'bin white with a eight now'],
#  ['dataset/waves/sgib8n.wav', 'set green in b eight now'],
#  ['dataset/waves/sgwp8n.wav', 'set green with p eight now'],
#  ['dataset/waves/lwaf1a.wav', 'lay white at f one again'],
#  ['dataset/waves/bwig3a.wav', 'bin white in g three again'],
#  ['dataset/waves/lgil5s.wav', 'lay green in l five soon'],
#  ['dataset/waves/sgiczp.wav', 'set green in c zero please'],
#  ['dataset/waves/pwip8p.wav', 'place white in p eight please'],
#  ['dataset/waves/bbil2n.wav', 'bin blue in l two now'],
#  ['dataset/waves/sbaa7a.wav', 'set blue at a seven again'],
#  ['dataset/waves/srwc1a.wav', 'set red with c one again'],
#  ['dataset/waves/lrwz5a.wav', 'lay red sp with z five again'],
#  ['dataset/waves/swib5a.wav', 'set white in b five again'],
#  ['dataset/waves/sgwp9s.wav', 'set green with p nine soon'],
#  ['dataset/waves/swbv4p.wav', 'set white by v four please'],
#  ['dataset/waves/pbbp3s.wav', 'place blue by p three soon'],
#  ['dataset/waves/pbwxzn.wav', 'place sp blue with x zero now'],
#  ['dataset/waves/swiu4n.wav', 'set white in u four now'],
#  ['dataset/waves/bram2n.wav', 'bin red at m two now'],
#  ['dataset/waves/priv7a.wav', 'place red in v seven again'],
#  ['dataset/waves/bbwgzn.wav', 'bin blue with g zero now'],
#  ['dataset/waves/lrbzzp.wav', 'lay red by z zero please'],
#  ['dataset/waves/lbix5s.wav', 'lay blue in x five soon'],
#  ['dataset/waves/brwt5s.wav', 'bin red with t five soon'],
#  ['dataset/waves/sria8p.wav', 'set red in a eight please'],
#  ['dataset/waves/pgiq3s.wav', 'place green in q three soon'],
#  ['dataset/waves/brbg5a.wav', 'bin red by g five again'],
#  ['dataset/waves/pbio6p.wav', 'place blue in o six please'],
#  ['dataset/waves/lwae8n.wav', 'lay white at e eight now'],
#  ['dataset/waves/lbiq3a.wav', 'lay blue in q three again'],
#  ['dataset/waves/srwb9s.wav', 'set red with b nine soon'],
#  ['dataset/waves/sgiv3a.wav', 'set green in v three again'],
#  ['dataset/waves/lgiz5a.wav', 'lay green in z five again'],
#  ['dataset/waves/lwbz7a.wav', 'lay white by z seven again'],
#  ['dataset/waves/bbwm5s.wav', 'bin blue with m five soon'],
#  ['dataset/waves/sbia1s.wav', 'set blue in a one soon'],
#  ['dataset/waves/bwaazn.wav', 'bin white at a zero now'],
#  ['dataset/waves/bwba6p.wav', 'bin white by a six please'],
#  ['dataset/waves/sban2n.wav', 'set blue at n two now'],
#  ['dataset/waves/sbbu3a.wav', 'set blue by u three again'],
#  ['dataset/waves/lbak1s.wav', 'lay blue at k one soon'],
#  ['dataset/waves/bwam8n.wav', 'bin white at m eight now'],
#  ['dataset/waves/lgbgzp.wav', 'lay green by g zero please'],
#  ['dataset/waves/lwilzp.wav', 'lay white in l zero please'],
#  ['dataset/waves/sgav7a.wav', 'set green at v seven again'],
#  ['dataset/waves/pgbk8p.wav', 'place green by k eight please'],
#  ['dataset/waves/sgai8p.wav', 'set green at i eight please'],
#  ['dataset/waves/lbbq8n.wav', 'lay blue by q eight now'],
#  ['dataset/waves/lwws5s.wav', 'lay white with s five soon'],
#  ['dataset/waves/lwbl7s.wav', 'lay white by l seven soon'],
#  ['dataset/waves/swio3a.wav', 'set white in o three again'],
#  ['dataset/waves/lwws7a.wav', 'lay white with s seven again'],
#  ['dataset/waves/lgaf5s.wav', 'lay green at f five soon'],
#  ['dataset/waves/lgaf4n.wav', 'lay green at f four now'],
#  ['dataset/waves/prwkzp.wav', 'place red with k zero please'],
#  ['dataset/waves/pwwy5a.wav', 'place white with y five again'],
#  ['dataset/waves/swwc7a.wav', 'set white with c seven again'],
#  ['dataset/waves/pbiu8n.wav', 'place blue in u eight now'],
#  ['dataset/waves/praj1s.wav', 'place red at j one soon'],
#  ['dataset/waves/sbbuzn.wav', 'set blue by u zero now'],
#  ['dataset/waves/bbas3a.wav', 'bin blue at s three again'],
#  ['dataset/waves/pwij5a.wav', 'place white in j five again'],
#  ['dataset/waves/sgwd3a.wav', 'set green with d three again'],
#  ['dataset/waves/pbbc6p.wav', 'place blue by c six please'],
#  ['dataset/waves/lgas2n.wav', 'lay green at s two now'],
#  ['dataset/waves/prac6n.wav', 'place red at c six now'],
#  ['dataset/waves/bwba5s.wav', 'bin white by a five soon'],
#  ['dataset/waves/sbaa4n.wav', 'set blue at a four now'],
#  ['dataset/waves/lbaq6p.wav', 'lay blue at q six please'],
#  ['dataset/waves/bwbn3s.wav', 'bin white by n three soon'],
#  ['dataset/waves/bwigzn.wav', 'bin white in g zero now'],
#  ['dataset/waves/bwbh1a.wav', 'bin white by h one again'],
#  ['dataset/waves/pbai5s.wav', 'place blue at i five soon'],
#  ['dataset/waves/bwwb1a.wav', 'bin white with b one again'],
#  ['dataset/waves/lrbr7a.wav', 'lay red by r seven again'],
#  ['dataset/waves/swwj1a.wav', 'set white with j one again'],
#  ['dataset/waves/sgac3s.wav', 'set green at c three soon'],
#  ['dataset/waves/bginzn.wav', 'bin green in n zero now'],
#  ['dataset/waves/lwbs2p.wav', 'lay white by s two please'],
#  ['dataset/waves/lbad7s.wav', 'lay blue at d seven soon'],
#  ['dataset/waves/pwwy4p.wav', 'place white with y four please'],
#  ['dataset/waves/lgif3a.wav', 'lay green in f three again'],
#  ['dataset/waves/sgii4p.wav', 'set green in i four please'],
#  ['dataset/waves/sgiv2p.wav', 'set green in v two please'],
#  ['dataset/waves/lbix4n.wav', 'lay blue in x four now'],
#  ['dataset/waves/lgwt1s.wav', 'lay green with t one soon'],
#  ['dataset/waves/prbj6p.wav', 'place red by j six please'],
#  ['dataset/waves/lbayzp.wav', 'lay blue at y zero please'],
#  ['dataset/waves/sgio6n.wav', 'set green in o six now'],
#  ['dataset/waves/pwbq7a.wav', 'place white by q seven again'],
#  ['dataset/waves/sgav6p.wav', 'set green at v six please'],
#  ['dataset/waves/brwa3s.wav', 'bin red with a three soon'],
#  ['dataset/waves/pwic8n.wav', 'place white in c eight now'],
#  ['dataset/waves/srbo5a.wav', 'set red by o five again'],
#  ['dataset/waves/sgbj1s.wav', 'set green by j one soon'],
#  ['dataset/waves/pbio7a.wav', 'place blue in o seven again'],
#  ['dataset/waves/lray6p.wav', 'lay red at y six please'],
#  ['dataset/waves/swbo8n.wav', 'set white by o eight now'],
#  ['dataset/waves/bgbn9s.wav', 'bin green by n nine soon'],
#  ['dataset/waves/bgig8p.wav', 'bin green in g eight please'],
#  ['dataset/waves/srihzn.wav', 'set red in h zero now'],
#  ['dataset/waves/sbwo3a.wav', 'set blue with o three again'],
#  ['dataset/waves/sgic1a.wav', 'set green in c one again'],
#  ['dataset/waves/sbwu5s.wav', 'set blue with u five soon'],
#  ['dataset/waves/bgin2p.wav', 'bin green in n two please'],
#  ['dataset/waves/sbba8n.wav', 'set blue by a eight now'],
#  ['dataset/waves/sriuzp.wav', 'set red in u zero please'],
#  ['dataset/waves/sbbn9a.wav', 'set blue by n nine again'],
#  ['dataset/waves/briz6n.wav', 'bin red in z six now'],
#  ['dataset/waves/braf9s.wav', 'bin red at f nine soon'],
#  ['dataset/waves/bbbs5s.wav', 'bin blue by s five soon'],
#  ['dataset/waves/swab6n.wav', 'set white at b six now'],
#  ['dataset/waves/srin5s.wav', 'set red in n five soon'],
#  ['dataset/waves/bbal7s.wav', 'bin blue at l seven soon'],
#  ['dataset/waves/bram4p.wav', 'bin red at m four please'],
#  ['dataset/waves/sbbh5a.wav', 'set blue by h five again'],
#  ['dataset/waves/swao7a.wav', 'set white at o seven again'],
#  ['dataset/waves/bgia3s.wav', 'bin green in a three soon'],
#  ['dataset/waves/srbb5s.wav', 'set red by b five soon'],
#  ['dataset/waves/lgwt2p.wav', 'lay green with t two please'],
#  ['dataset/waves/brbt2p.wav', 'bin red by t two please'],
#  ['dataset/waves/pgwy8n.wav', 'place green with y eight now'],
#  ['dataset/waves/lwbz6p.wav', 'lay white by z six please'],
#  ['dataset/waves/pbbi8n.wav', 'place blue by i eight now'],
#  ['dataset/waves/sgbp6p.wav', 'set green by p six please'],
#  ['dataset/waves/srbi1a.wav', 'set red by i one again'],
#  ['dataset/waves/bgan4n.wav', 'bin green at n four now'],
#  ['dataset/waves/sgii3s.wav', 'set green in i three soon'],
#  ['dataset/waves/swao6p.wav', 'set white at o six please'],
#  ['dataset/waves/pbac1s.wav', 'place blue at c one soon'],
#  ['dataset/waves/pwwk5s.wav', 'place white with k five soon'],
#  ['dataset/waves/lgis1a.wav', 'lay green in s one again'],
#  ['dataset/waves/lwie7a.wav', 'lay white in e seven again'],
#  ['dataset/waves/pwbd8p.wav', 'place white by d eight please'],
#  ['dataset/waves/lgas5a.wav', 'lay green at s five again'],
#  ['dataset/waves/briz7s.wav', 'bin red in z seven soon'],
#  ['dataset/waves/pwbd6n.wav', 'place white by d six now'],
#  ['dataset/waves/sgbp7a.wav', 'set green by p seven again'],
#  ['dataset/waves/pwaj6n.wav', 'place white at j six now'],
#  ['dataset/waves/srih1s.wav', 'set red in h one soon'],
#  ['dataset/waves/lrbr4n.wav', 'lay red by r four now'],
#  ['dataset/waves/bwbt7s.wav', 'bin white by t seven soon'],
#  ['dataset/waves/bgahzn.wav', 'bin green at h zero now'],
#  ['dataset/waves/pbbc4n.wav', 'place blue by c four now'],
#  ['dataset/waves/bgau1a.wav', 'bin green at u one again'],
#  ['dataset/waves/pgwe9a.wav', 'place green with e nine again'],
#  ['dataset/waves/lrar1s.wav', 'lay red at r one soon'],
#  ['dataset/waves/bgbozp.wav', 'bin green by o zero please'],
#  ['dataset/waves/brwa4p.wav', 'bin red with a four please'],
#  ['dataset/waves/lgaz9a.wav', 'lay green at z nine again'],
#  ['dataset/waves/pbbc5s.wav', 'place blue by c five soon'],
#  ['dataset/waves/lbwe6p.wav', 'lay blue sp with e six please'],
#  ['dataset/waves/lgwg3s.wav', 'lay green with g three soon'],
#  ['dataset/waves/srab2p.wav', 'set red at b two please'],
#  ['dataset/waves/lgal8n.wav', 'lay green at l eight now'],
#  ['dataset/waves/lwws4n.wav', 'lay white with s four now'],
#  ['dataset/waves/swbv3s.wav', 'set white by v three soon'],
#  ['dataset/waves/bwag4n.wav', 'bin white at g four now'],
#  ['dataset/waves/prbd2p.wav', 'place red by d two please'],
#  ['dataset/waves/srwo8p.wav', 'set red with o eight please'],
#  ['dataset/waves/bwbt6n.wav', 'bin white by t six now'],
#  ['dataset/waves/pgbk9a.wav', 'place green by k nine again'],
#  ['dataset/waves/bwwu2p.wav', 'bin white with u two please'],
#  ['dataset/waves/swau8n.wav', 'set white at u eight now'],
#  ['dataset/waves/sbat9a.wav', 'set blue at t nine again'],
#  ['dataset/waves/pbaczn.wav', 'place blue at c zero now'],
#  ['dataset/waves/bwbn5a.wav', 'bin white by n five again'],
#  ['dataset/waves/srbh8n.wav', 'set red by h eight now'],
#  ['dataset/waves/praj2p.wav', 'place red at j two please'],
#  ['dataset/waves/swbv2n.wav', 'set white by v two now'],
#  ['dataset/waves/bwim6p.wav', 'bin white in m six please'],
#  ['dataset/waves/bwim4n.wav', 'bin white in m four now'],
#  ['dataset/waves/pwaqzn.wav', 'place white at q zero now'],
#  ['dataset/waves/pgbe3s.wav', 'place green by e three soon'],
#  ['dataset/waves/srwi2n.wav', 'set red with i two now'],
#  ['dataset/waves/bwwu1s.wav', 'bin white with u one soon'],
#  ['dataset/waves/sgwd1s.wav', 'set green with d one soon'],
#  ['dataset/waves/lrws1a.wav', 'lay red with s one again'],
#  ['dataset/waves/bwig2p.wav', 'bin white in g two please'],
#  ['dataset/waves/swwi9s.wav', 'set white with i nine soon'],
#  ['dataset/waves/sbia3a.wav', 'set blue in a three again'],
#  ['dataset/waves/prbd3a.wav', 'place red by d three again'],
#  ['dataset/waves/lrwf3a.wav', 'lay red with f three again'],
#  ['dataset/waves/bwim7a.wav', 'bin white in m seven again'],
#  ['dataset/waves/sbig7a.wav', 'set blue in g seven again'],
#  ['dataset/waves/sgai6n.wav', 'set green at i six now'],
#  ['dataset/waves/bbbf6n.wav', 'bin blue by f six now'],
#  ['dataset/waves/sbig4n.wav', 'set blue in g four now'],
#  ['dataset/waves/srwo7s.wav', 'set red with o seven soon'],
#  ['dataset/waves/bbbm3a.wav', 'bin blue by m three again'],
#  ['dataset/waves/lgwg5a.wav', 'lay green with g five again'],
#  ['dataset/waves/lwik8n.wav', 'lay white in k eight now'],
#  ['dataset/waves/bwis8n.wav', 'bin white in s eight now'],
#  ['dataset/waves/lbwlzp.wav', 'lay blue with l zero please'],
#  ['dataset/waves/sbwb4p.wav', 'set blue with b four please'],
#  ['dataset/waves/swaizn.wav', 'set white at i zero now'],
#  ['dataset/waves/lbwy7s.wav', 'lay blue with y seven soon'],
#  ['dataset/waves/bwam9s.wav', 'bin white at m nine soon'],
#  ['dataset/waves/bwwn8p.wav', 'bin white with n eight please'],
#  ['dataset/waves/bbws9s.wav', 'bin blue with s nine soon'],
#  ['dataset/waves/lgal9s.wav', 'lay green at l nine soon'],
#  ['dataset/waves/pbwdzp.wav', 'place blue with d zero please'],
#  ['dataset/waves/pgij9s.wav', 'place green in j nine soon'],
#  ['dataset/waves/lrak9a.wav', 'lay red at k nine again'],
#  ['dataset/waves/pgak3s.wav', 'place green at k three soon'],
#  ['dataset/waves/pwad3s.wav', 'place white at d three soon'],
#  ['dataset/waves/pwij3s.wav', 'place white in j three soon'],
#  ['dataset/waves/lwir5a.wav', 'lay white in r five again'],
#  ['dataset/waves/lwbf3s.wav', 'lay white sp by f three soon'],
#  ['dataset/waves/lbbk7a.wav', 'lay blue by k seven again'],
#  ['dataset/waves/bgan7a.wav', 'bin green at n seven again'],
#  ['dataset/waves/sgiv1s.wav', 'set green in v one soon'],
#  ['dataset/waves/bwbn4p.wav', 'bin white sp by n four please'],
#  ['dataset/waves/lrid9s.wav', 'lay red in d nine soon'],
#  ['dataset/waves/bram3s.wav', 'bin red at m three soon'],
#  ['dataset/waves/pwid1a.wav', 'place white in d one again'],
#  ['dataset/waves/bbbs6p.wav', 'bin blue by s six please'],
#  ['dataset/waves/sgbc8p.wav', 'set green by c eight please'],
#  ['dataset/waves/lgwm9a.wav', 'lay green with m nine again'],
#  ['dataset/waves/sbwu4n.wav', 'set blue with u four now'],
#  ['dataset/waves/pgbr1s.wav', 'place green by r one soon'],
#  ['dataset/waves/bbbz8n.wav', 'bin blue by z eight now'],
#  ['dataset/waves/bgaa8p.wav', 'bin green at a eight please'],
#  ['dataset/waves/pbao9s.wav', 'place blue at o nine soon'],
#  ['dataset/waves/swbc1s.wav', 'set white by c one soon'],
#  ['dataset/waves/lbby4p.wav', 'lay blue by y four please'],
#  ['dataset/waves/lrik2n.wav', 'lay red in k two now'],
#  ['dataset/waves/sgio7s.wav', 'set green in o seven soon'],
#  ['dataset/waves/bbbf8p.wav', 'bin blue by f eight please'],
#  ['dataset/waves/srau5a.wav', 'set red at u five again'],
#  ['dataset/waves/lbij7s.wav', 'lay blue in j seven soon'],
#  ['dataset/waves/pbai6p.wav', 'place sp blue at i six please'],
#  ['dataset/waves/sbat8p.wav', 'set blue at t eight please'],
#  ['dataset/waves/brag1a.wav', 'bin red at g one again'],
#  ['dataset/waves/swao4n.wav', 'set white at o four now'],
#  ['dataset/waves/lriy3a.wav', 'lay red in y three again'],
#  ['dataset/waves/bbaz7a.wav', 'bin blue at z seven again'],
#  ['dataset/waves/lbbezn.wav', 'lay blue by e zero now'],
#  ['dataset/waves/swwjzp.wav', 'set white with j zero please'],
#  ['dataset/waves/lbix7a.wav', 'lay blue in x seven again'],
#  ['dataset/waves/pbib9a.wav', 'place blue in b nine again'],
#  ['dataset/waves/sgwj6p.wav', 'set green with j six please'],
#  ['dataset/waves/pbbj1a.wav', 'place blue by j one again'],
#  ['dataset/waves/sgbj3a.wav', 'set green by j three again'],
#  ['dataset/waves/sbia2p.wav', 'set blue in a two please'],
#  ['dataset/waves/lrbz1a.wav', 'lay red by z one again'],
#  ['dataset/waves/lrbl3a.wav', 'lay red by l three again'],
#  ['dataset/waves/pwwy2n.wav', 'place white with y two now'],
#  ['dataset/waves/lriq9a.wav', 'lay red in q nine again'],
#  ['dataset/waves/bwat3s.wav', 'bin white at t three soon'],
#  ['dataset/waves/pwbd9a.wav', 'place white by d nine again'],
#  ['dataset/waves/sbwozn.wav', 'set blue with o zero now'],
#  ['dataset/waves/lrbl2p.wav', 'lay red by l two please'],
#  ['dataset/waves/bgat9s.wav', 'bin green at t nine soon'],
#  ['dataset/waves/bbaf2n.wav', 'bin blue at f two now'],
#  ['dataset/waves/sgii2n.wav', 'set green in i two now'],
#  ['dataset/waves/pwwq8n.wav', 'place white with q eight now'],
#  ['dataset/waves/bras6n.wav', 'bin red at s six now'],
#  ['dataset/waves/prbd1s.wav', 'place red by d one soon'],
#  ['dataset/waves/sgivzn.wav', 'set green in v zero now'],
#  ['dataset/waves/lwik9s.wav', 'lay white in k nine soon'],
#  ['dataset/waves/bwwu3a.wav', 'bin white with u three again'],
#  ['dataset/waves/pbai4n.wav', 'place blue at i four now'],
#  ['dataset/waves/srah4n.wav', 'set red at h four now'],
#  ['dataset/waves/pbwj2n.wav', 'place blue with j two now'],
#  ['dataset/waves/pbwj4p.wav', 'place blue with j four please'],
#  ['dataset/waves/sbiazn.wav', 'set blue in a zero now'],
#  ['dataset/waves/lgiz3s.wav', 'lay green in z three soon'],
#  ['dataset/waves/lwar8p.wav', 'lay white at r eight please'],
#  ['dataset/waves/lbwr3s.wav', 'lay blue with r three soon'],
#  ['dataset/waves/bgwu9a.wav', 'bin green with u nine again'],
#  ['dataset/waves/bgah2p.wav', 'bin green at h two please'],
#  ['dataset/waves/swwp5a.wav', 'set white with p five again'],
#  ['dataset/waves/lgas3s.wav', 'lay green at s three soon'],
#  ['dataset/waves/lwil1a.wav', 'lay white in l one again'],
#  ['dataset/waves/lgwtzn.wav', 'lay green with t zero now'],
#  ['dataset/waves/prbp8n.wav', 'place red by p eight now'],
#  ['dataset/waves/pbai7a.wav', 'place blue at i seven again'],
#  ['dataset/waves/lgif2p.wav', 'lay green in f two please'],
#  ['dataset/waves/prwx9a.wav', 'place red with x nine again'],
#  ['dataset/waves/lwbs3a.wav', 'lay white by s three again'],
#  ['dataset/waves/srin6p.wav', 'set red in n six please'],
#  ['dataset/waves/bbas2p.wav', 'bin blue at s two please'],
#  ['dataset/waves/lrwr9s.wav', 'lay red with r nine soon'],
#  ['dataset/waves/briz9a.wav', 'bin red in z nine again'],
#  ['dataset/waves/pwbk2p.wav', 'place white by k two please'],
#  ['dataset/waves/lwiy9a.wav', 'lay white in y nine again'],
#  ['dataset/waves/pwax4n.wav', 'place white at x four now'],
#  ['dataset/waves/lgaz6n.wav', 'lay green at z six now'],
#  ['dataset/waves/pgak5a.wav', 'place green at k five again'],
#  ['dataset/waves/sbag9s.wav', 'set blue at g nine soon'],
#  ['dataset/waves/pgid5s.wav', 'place green in d five soon'],
#  ['dataset/waves/bbaszn.wav', 'bin blue at s zero now'],
#  ['dataset/waves/srwi4p.wav', 'set red with i four please'],
#  ['dataset/waves/srbb6p.wav', 'set red by b six please'],
#  ['dataset/waves/pbwp6n.wav', 'place blue with p six now'],
#  ['dataset/waves/lwwz8n.wav', 'lay white with z eight now'],
#  ['dataset/waves/pwaq1s.wav', 'place white at q one soon'],
#  ['dataset/waves/sgac4p.wav', 'set green at c four sp please'],
#  ['dataset/waves/lgbs9a.wav', 'lay green by s nine again'],
#  ['dataset/waves/brwa5a.wav', 'bin red with a five again'],
#  ['dataset/waves/pwbq6p.wav', 'place white by q six please'],
#  ['dataset/waves/bbbf9a.wav', 'bin blue by f nine again'],
#  ['dataset/waves/braf8n.wav', 'bin red at f eight now'],
#  ['dataset/waves/bgwb6p.wav', 'bin green with b six please'],
#  ['dataset/waves/sbit4p.wav', 'set blue in t four please'],
#  ['dataset/waves/pwax7a.wav', 'place white at x seven again'],
#  ['dataset/waves/prajzn.wav', 'place red at j zero now'],
#  ['dataset/waves/sgbj2p.wav', 'set green by j two please'],
#  ['dataset/waves/swwp3s.wav', 'set white with p three soon'],
#  ['dataset/waves/sriu1a.wav', 'set red in u one again'],
#  ['dataset/waves/lbwk8n.wav', 'lay blue with k eight now'],
#  ['dataset/waves/pwbx8n.wav', 'place white by x eight now'],
#  ['dataset/waves/brbt1s.wav', 'bin red by t one soon'],
#  ['dataset/waves/lgbs8p.wav', 'lay green by s eight please'],
#  ['dataset/waves/pwbq4n.wav', 'place white by q four now'],
#  ['dataset/waves/sbit2n.wav', 'set blue in t two now'],
#  ['dataset/waves/lgas4p.wav', 'lay green at s four please'],
#  ['dataset/waves/lwbl9a.wav', 'lay white by l nine again'],
#  ['dataset/waves/priv6p.wav', 'place red in v six please'],
#  ['dataset/waves/pwad5a.wav', 'place white at d five again'],
#  ['dataset/waves/lgbg1a.wav', 'lay green by g one again'],
#  ['dataset/waves/sbbh2n.wav', 'set blue by h two now'],
#  ['dataset/waves/bragzp.wav', 'bin red at g zero please'],
#  ['dataset/waves/srah6p.wav', 'set red at h six please'],
#  ['dataset/waves/brif5s.wav', 'bin red in f five soon'],
#  ['dataset/waves/lbid3s.wav', 'lay blue in d three soon'],
#  ['dataset/waves/prwx7s.wav', 'place red with x seven soon'],
#  ['dataset/waves/lrwl4n.wav', 'lay red with l four now'],
#  ['dataset/waves/swiu7a.wav', 'set white in u seven again'],
#  ['dataset/waves/lriq8p.wav', 'lay red in q eight please'],
#  ['dataset/waves/lbaq7a.wav', 'lay blue at q seven again'],
#  ['dataset/waves/bgwo2n.wav', 'bin green with o two now'],
#  ['dataset/waves/bgit6p.wav', 'bin green in t six please'],
#  ['dataset/waves/bwat2n.wav', 'bin white at t two now'],
#  ['dataset/waves/srwi5a.wav', 'set red with i five again'],
#  ['dataset/waves/pgid6p.wav', 'place green in d six please'],
#  ['dataset/waves/bris4p.wav', 'bin red in s four please'],
#  ['dataset/waves/bwag5s.wav', 'bin white at g five soon'],
#  ['dataset/waves/sbaa6p.wav', 'set blue at a six please'],
#  ['dataset/waves/pwwe1s.wav', 'place white with e one soon'],
#  ['dataset/waves/lwwz9s.wav', 'lay white with z nine soon'],
#  ['dataset/waves/prbx2n.wav', 'place red by x two now'],
#  ['dataset/waves/bbws8n.wav', 'bin blue with s eight now'],
#  ['dataset/waves/pbav4p.wav', 'place blue at v four please'],
#  ['dataset/waves/sbit3s.wav', 'set blue in t three soon'],
#  ['dataset/waves/pbbp5a.wav', 'place blue by p five again'],
#  ['dataset/waves/pbio4n.wav', 'place blue in o four now'],
#  ['dataset/waves/sria6n.wav', 'set red in a six now'],
#  ['dataset/waves/sgap2p.wav', 'set green at p two please'],
#  ['dataset/waves/bras7s.wav', 'bin red at s seven soon'],
#  ['dataset/waves/bwba4n.wav', 'bin white by a four now'],
#  ['dataset/waves/pwbyzp.wav', 'place white by y zero please'],
#  ['dataset/waves/pgbk7s.wav', 'place green by k seven soon'],
#  ['dataset/waves/prax1a.wav', 'place red at x one again']]

# %%
configs = ModelConfigs()
configs.frame_length
# Out:
# 256

# %%
max_text_length, max_spectrogram_length = 0, 0
for file_path, label in tqdm(dataset):
    spectrogram = WavReader.get_spectrogram(file_path, frame_length=configs.frame_length, frame_step=configs.frame_step, fft_length=configs.fft_length)
    valid_label = [c for c in label if c in configs.vocab]
    max_text_length = max(max_text_length, len(valid_label))
    max_spectrogram_length = max(max_spectrogram_length, spectrogram.shape[0])
    configs.input_shape = [max_spectrogram_length, spectrogram.shape[1]]

configs.max_spectrogram_length = max_spectrogram_length
configs.max_text_length = max_text_length
configs.save()
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 80.73it/s]

# %%
data_provider = DataProvider(
    dataset=dataset,
    skip_validation=True,
    batch_size=configs.batch_size,
    data_preprocessors=[
        WavReader(frame_length=configs.frame_length, frame_step=configs.frame_step, fft_length=configs.fft_length),
        ],
    transformers=[
        SpectrogramPadding(max_spectrogram_length=configs.max_spectrogram_length, padding_value=0),
        LabelIndexer(configs.vocab),
        LabelPadding(max_word_length=configs.max_text_length, padding_value=len(configs.vocab)),
        ],
)
# Out:
# INFO:DataProvider:Skipping Dataset validation...

# %%
train_data_provider, val_data_provider = data_provider.split(split = 0.9)

# %%
model = train_model(
    input_dim = configs.input_shape,
    output_dim = len(configs.vocab),
    dropout=0.5
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=configs.learning_rate),
    loss=CTCloss(),
    metrics=[
        CERMetric(vocabulary=configs.vocab),
        WERMetric(vocabulary=configs.vocab)
        ],
    run_eagerly=False
)

# %%
model.summary(line_length=110)
# Out:
# Model: "model"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  input (InputLayer)                              [(None, 414, 193)]                          0
#
#  lambda (Lambda)                                 (None, 414, 193, 1)                         0
#
#  conv2d (Conv2D)                                 (None, 207, 97, 32)                         14432
#
#  batch_normalization (BatchNormalization)        (None, 207, 97, 32)                         128
#
#  leaky_re_lu (LeakyReLU)                         (None, 207, 97, 32)                         0
#
#  conv2d_1 (Conv2D)                               (None, 207, 49, 32)                         236544
#
#  batch_normalization_1 (BatchNormalization)      (None, 207, 49, 32)                         128
#
#  leaky_re_lu_1 (LeakyReLU)                       (None, 207, 49, 32)                         0
#
#  reshape (Reshape)                               (None, 207, 1568)                           0
#
#  bidirectional (Bidirectional)                   (None, 207, 256)                            1737728
#
#  dropout (Dropout)                               (None, 207, 256)                            0
#
#  bidirectional_1 (Bidirectional)                 (None, 207, 256)                            394240
#
#  dropout_1 (Dropout)                             (None, 207, 256)                            0
#
#  bidirectional_2 (Bidirectional)                 (None, 207, 256)                            394240
#
#  dropout_2 (Dropout)                             (None, 207, 256)                            0
#
#  bidirectional_3 (Bidirectional)                 (None, 207, 256)                            394240
#
#  dropout_3 (Dropout)                             (None, 207, 256)                            0
#
#  bidirectional_4 (Bidirectional)                 (None, 207, 256)                            394240
#
#  dense (Dense)                                   (None, 207, 256)                            65792
#
#  leaky_re_lu_2 (LeakyReLU)                       (None, 207, 256)                            0
#
#  dropout_4 (Dropout)                             (None, 207, 256)                            0
#
#  dense_1 (Dense)                                 (None, 207, 28)                             7196
#
# ==============================================================================================================
# Total params: 3638908 (13.88 MB)
# Trainable params: 3638780 (13.88 MB)
# Non-trainable params: 128 (512.00 Byte)
# ______________________________________________________________________________________________________________

# %%
earlystopper = EarlyStopping(monitor="val_CER", patience=20, verbose=1, mode="min")
checkpoint = ModelCheckpoint(f"{configs.model_path}/model.h5", monitor="val_CER", verbose=1, save_best_only=True, mode="min")
trainLogger = TrainLogger(configs.model_path)
tb_callback = TensorBoard(f"{configs.model_path}/logs", update_freq=1)
reduceLROnPlat = ReduceLROnPlateau(monitor="val_CER", factor=0.8, min_delta=1e-10, patience=5, verbose=1, mode="auto")
model2onnx = Model2onnx(f"{configs.model_path}/model.h5")

# %%
# model.load_weights('/content/Models/05_sound_to_text/202310062238/model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-772da81a4b93> in <cell line: 1>()
# ----> 1 model.load_weights('/content/Models/05_sound_to_text/202310062238/model.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in _assign_value_to_variable(variable, value)
#    4359     else:
#    4360         # For the normal tf.Variable assign
# -> 4361         variable.assign(value)
#    4362
#    4363
#
# ValueError: Cannot assign value to variable ' dense_1/kernel:0': Shape mismatch.The variable shape (256, 28), and the assigned value shape (256, 31) are incompatible.

# %%
model.fit(
    train_data_provider,
    validation_data=val_data_provider,
    epochs=configs.train_epochs,
    callbacks=[earlystopper, checkpoint, trainLogger, reduceLROnPlat, tb_callback, model2onnx],
    workers=configs.train_workers
)
# Out:
# Epoch 1/1000
# 113/113 [==============================] - ETA: 0s - loss: 97.7444 - CER: 0.9987 - WER: 1.2176
# Epoch 1: val_CER improved from inf to 0.63526, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 54s 239ms/step - loss: 97.7444 - CER: 0.9987 - WER: 1.2176 - val_loss: 46.4006 - val_CER: 0.6353 - val_WER: 0.9933 - lr: 5.0000e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/1000
# 113/113 [==============================] - ETA: 0s - loss: 45.1180 - CER: 0.5716 - WER: 0.9645
# Epoch 2: val_CER improved from 0.63526 to 0.53366, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 22s 190ms/step - loss: 45.1180 - CER: 0.5716 - WER: 0.9645 - val_loss: 38.0418 - val_CER: 0.5337 - val_WER: 0.8607 - lr: 5.0000e-04
# Epoch 3/1000
# 113/113 [==============================] - ETA: 0s - loss: 38.8769 - CER: 0.5100 - WER: 0.8736
# Epoch 3: val_CER improved from 0.53366 to 0.43705, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 25s 215ms/step - loss: 38.8769 - CER: 0.5100 - WER: 0.8736 - val_loss: 32.8479 - val_CER: 0.4370 - val_WER: 0.7910 - lr: 5.0000e-04
# Epoch 4/1000
# 113/113 [==============================] - ETA: 0s - loss: 34.5603 - CER: 0.4713 - WER: 0.8107
# Epoch 4: val_CER did not improve from 0.43705
# 113/113 [==============================] - 22s 189ms/step - loss: 34.5603 - CER: 0.4713 - WER: 0.8107 - val_loss: 30.9602 - val_CER: 0.4520 - val_WER: 0.7876 - lr: 5.0000e-04
# Epoch 5/1000
# 113/113 [==============================] - ETA: 0s - loss: 33.3491 - CER: 0.4696 - WER: 0.8039
# Epoch 5: val_CER did not improve from 0.43705
# 113/113 [==============================] - 28s 238ms/step - loss: 33.3491 - CER: 0.4696 - WER: 0.8039 - val_loss: 30.2324 - val_CER: 0.4423 - val_WER: 0.7562 - lr: 5.0000e-04
# Epoch 6/1000
# 113/113 [==============================] - ETA: 0s - loss: 32.6586 - CER: 0.4761 - WER: 0.7980
# Epoch 6: val_CER did not improve from 0.43705
# 113/113 [==============================] - 28s 238ms/step - loss: 32.6586 - CER: 0.4761 - WER: 0.7980 - val_loss: 29.9396 - val_CER: 0.4529 - val_WER: 0.7876 - lr: 5.0000e-04
# Epoch 7/1000
# 113/113 [==============================] - ETA: 0s - loss: 31.2617 - CER: 0.4629 - WER: 0.7861
# Epoch 7: val_CER did not improve from 0.43705
# 113/113 [==============================] - 23s 200ms/step - loss: 31.2617 - CER: 0.4629 - WER: 0.7861 - val_loss: 28.6289 - val_CER: 0.4596 - val_WER: 0.7860 - lr: 5.0000e-04
# Epoch 8/1000
# 113/113 [==============================] - ETA: 0s - loss: 30.3432 - CER: 0.4599 - WER: 0.7851
# Epoch 8: val_CER did not improve from 0.43705
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 113/113 [==============================] - 28s 238ms/step - loss: 30.3432 - CER: 0.4599 - WER: 0.7851 - val_loss: 28.1463 - val_CER: 0.4525 - val_WER: 0.7876 - lr: 5.0000e-04
# Epoch 9/1000
# 113/113 [==============================] - ETA: 0s - loss: 29.6956 - CER: 0.4550 - WER: 0.7875
# Epoch 9: val_CER improved from 0.43705 to 0.43441, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 24s 201ms/step - loss: 29.6956 - CER: 0.4550 - WER: 0.7875 - val_loss: 27.4096 - val_CER: 0.4344 - val_WER: 0.7512 - lr: 4.0000e-04
# Epoch 10/1000
# 113/113 [==============================] - ETA: 0s - loss: 30.9474 - CER: 0.4632 - WER: 0.7995
# Epoch 10: val_CER did not improve from 0.43441
# 113/113 [==============================] - 25s 215ms/step - loss: 30.9474 - CER: 0.4632 - WER: 0.7995 - val_loss: 27.8281 - val_CER: 0.4386 - val_WER: 0.7529 - lr: 4.0000e-04
# Epoch 11/1000
# 113/113 [==============================] - ETA: 0s - loss: 28.9718 - CER: 0.4545 - WER: 0.7854
# Epoch 11: val_CER did not improve from 0.43441
# 113/113 [==============================] - 26s 219ms/step - loss: 28.9718 - CER: 0.4545 - WER: 0.7854 - val_loss: 27.3181 - val_CER: 0.4423 - val_WER: 0.7512 - lr: 4.0000e-04
# Epoch 12/1000
# 113/113 [==============================] - ETA: 0s - loss: 29.2550 - CER: 0.4580 - WER: 0.7854
# Epoch 12: val_CER did not improve from 0.43441
# 113/113 [==============================] - 25s 215ms/step - loss: 29.2550 - CER: 0.4580 - WER: 0.7854 - val_loss: 30.6181 - val_CER: 0.4551 - val_WER: 0.7943 - lr: 4.0000e-04
# Epoch 13/1000
# 113/113 [==============================] - ETA: 0s - loss: 28.9020 - CER: 0.4534 - WER: 0.7871
# Epoch 13: val_CER did not improve from 0.43441
# 113/113 [==============================] - 25s 216ms/step - loss: 28.9020 - CER: 0.4534 - WER: 0.7871 - val_loss: 27.0550 - val_CER: 0.4365 - val_WER: 0.7312 - lr: 4.0000e-04
# Epoch 14/1000
# 113/113 [==============================] - ETA: 0s - loss: 27.8221 - CER: 0.4492 - WER: 0.7775
# Epoch 14: val_CER did not improve from 0.43441
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00032000001519918444.
# 113/113 [==============================] - 22s 190ms/step - loss: 27.8221 - CER: 0.4492 - WER: 0.7775 - val_loss: 26.4353 - val_CER: 0.4417 - val_WER: 0.7529 - lr: 4.0000e-04
# Epoch 15/1000
# 113/113 [==============================] - ETA: 0s - loss: 27.8345 - CER: 0.4542 - WER: 0.7833
# Epoch 15: val_CER did not improve from 0.43441
# 113/113 [==============================] - 25s 211ms/step - loss: 27.8345 - CER: 0.4542 - WER: 0.7833 - val_loss: 26.3931 - val_CER: 0.4546 - val_WER: 0.7826 - lr: 3.2000e-04
# Epoch 16/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.9563 - CER: 0.4499 - WER: 0.7835
# Epoch 16: val_CER did not improve from 0.43441
# 113/113 [==============================] - 28s 240ms/step - loss: 26.9563 - CER: 0.4499 - WER: 0.7835 - val_loss: 26.4350 - val_CER: 0.4427 - val_WER: 0.7512 - lr: 3.2000e-04
# Epoch 17/1000
# 113/113 [==============================] - ETA: 0s - loss: 27.4413 - CER: 0.4453 - WER: 0.7779
# Epoch 17: val_CER improved from 0.43441 to 0.43084, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 23s 201ms/step - loss: 27.4413 - CER: 0.4453 - WER: 0.7779 - val_loss: 26.3922 - val_CER: 0.4308 - val_WER: 0.7676 - lr: 3.2000e-04
# Epoch 18/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.7404 - CER: 0.4479 - WER: 0.7866
# Epoch 18: val_CER did not improve from 0.43084
# 113/113 [==============================] - 25s 213ms/step - loss: 26.7404 - CER: 0.4479 - WER: 0.7866 - val_loss: 25.4172 - val_CER: 0.4432 - val_WER: 0.7910 - lr: 3.2000e-04
# Epoch 19/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.3419 - CER: 0.4455 - WER: 0.7798
# Epoch 19: val_CER did not improve from 0.43084
# 113/113 [==============================] - 24s 203ms/step - loss: 26.3419 - CER: 0.4455 - WER: 0.7798 - val_loss: 25.6945 - val_CER: 0.4348 - val_WER: 0.7643 - lr: 3.2000e-04
# Epoch 20/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.2224 - CER: 0.4459 - WER: 0.7833
# Epoch 20: val_CER improved from 0.43084 to 0.42305, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 24s 199ms/step - loss: 26.2224 - CER: 0.4459 - WER: 0.7833 - val_loss: 24.7806 - val_CER: 0.4231 - val_WER: 0.7712 - lr: 3.2000e-04
# Epoch 21/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.8981 - CER: 0.4480 - WER: 0.7828
# Epoch 21: val_CER did not improve from 0.42305
# 113/113 [==============================] - 25s 219ms/step - loss: 25.8981 - CER: 0.4480 - WER: 0.7828 - val_loss: 25.6849 - val_CER: 0.4350 - val_WER: 0.7826 - lr: 3.2000e-04
# Epoch 22/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.7193 - CER: 0.4456 - WER: 0.7849
# Epoch 22: val_CER did not improve from 0.42305
# 113/113 [==============================] - 24s 204ms/step - loss: 25.7193 - CER: 0.4456 - WER: 0.7849 - val_loss: 24.5694 - val_CER: 0.4376 - val_WER: 0.7529 - lr: 3.2000e-04
# Epoch 23/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.3355 - CER: 0.4434 - WER: 0.7781
# Epoch 23: val_CER did not improve from 0.42305
# 113/113 [==============================] - 22s 191ms/step - loss: 25.3355 - CER: 0.4434 - WER: 0.7781 - val_loss: 24.2963 - val_CER: 0.4339 - val_WER: 0.7362 - lr: 3.2000e-04
# Epoch 24/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.4011 - CER: 0.4413 - WER: 0.7792
# Epoch 24: val_CER did not improve from 0.42305
# 113/113 [==============================] - 25s 214ms/step - loss: 25.4011 - CER: 0.4413 - WER: 0.7792 - val_loss: 24.7393 - val_CER: 0.4232 - val_WER: 0.7529 - lr: 3.2000e-04
# Epoch 25/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.0277 - CER: 0.4420 - WER: 0.7762
# Epoch 25: val_CER did not improve from 0.42305
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002560000168159604.
# 113/113 [==============================] - 24s 205ms/step - loss: 26.0277 - CER: 0.4420 - WER: 0.7762 - val_loss: 24.5075 - val_CER: 0.4270 - val_WER: 0.7810 - lr: 3.2000e-04
# Epoch 26/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.3317 - CER: 0.4409 - WER: 0.7817
# Epoch 26: val_CER improved from 0.42305 to 0.41063, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 24s 202ms/step - loss: 25.3317 - CER: 0.4409 - WER: 0.7817 - val_loss: 23.9741 - val_CER: 0.4106 - val_WER: 0.7479 - lr: 2.5600e-04
# Epoch 27/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.1587 - CER: 0.4397 - WER: 0.7854
# Epoch 27: val_CER did not improve from 0.41063
# 113/113 [==============================] - 24s 207ms/step - loss: 25.1587 - CER: 0.4397 - WER: 0.7854 - val_loss: 24.3241 - val_CER: 0.4161 - val_WER: 0.7445 - lr: 2.5600e-04
# Epoch 28/1000
# 113/113 [==============================] - ETA: 0s - loss: 27.6785 - CER: 0.4446 - WER: 0.7911
# Epoch 28: val_CER did not improve from 0.41063
# 113/113 [==============================] - 23s 200ms/step - loss: 27.6785 - CER: 0.4446 - WER: 0.7911 - val_loss: 24.2862 - val_CER: 0.4226 - val_WER: 0.7379 - lr: 2.5600e-04
# Epoch 29/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.0063 - CER: 0.4324 - WER: 0.7801
# Epoch 29: val_CER did not improve from 0.41063
# 113/113 [==============================] - 27s 228ms/step - loss: 25.0063 - CER: 0.4324 - WER: 0.7801 - val_loss: 23.9000 - val_CER: 0.4183 - val_WER: 0.7795 - lr: 2.5600e-04
# Epoch 30/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.0100 - CER: 0.4280 - WER: 0.7766
# Epoch 30: val_CER improved from 0.41063 to 0.39896, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 23s 196ms/step - loss: 25.0100 - CER: 0.4280 - WER: 0.7766 - val_loss: 23.8586 - val_CER: 0.3990 - val_WER: 0.7412 - lr: 2.5600e-04
# Epoch 31/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.5823 - CER: 0.4246 - WER: 0.7782
# Epoch 31: val_CER did not improve from 0.39896
# 113/113 [==============================] - 29s 247ms/step - loss: 24.5823 - CER: 0.4246 - WER: 0.7782 - val_loss: 23.6360 - val_CER: 0.4015 - val_WER: 0.7760 - lr: 2.5600e-04
# Epoch 32/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.4534 - CER: 0.4239 - WER: 0.7744
# Epoch 32: val_CER did not improve from 0.39896
# 113/113 [==============================] - 23s 193ms/step - loss: 24.4534 - CER: 0.4239 - WER: 0.7744 - val_loss: 24.8746 - val_CER: 0.4127 - val_WER: 0.7479 - lr: 2.5600e-04
# Epoch 33/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.6294 - CER: 0.4219 - WER: 0.7722
# Epoch 33: val_CER improved from 0.39896 to 0.39392, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 23s 196ms/step - loss: 24.6294 - CER: 0.4219 - WER: 0.7722 - val_loss: 24.8660 - val_CER: 0.3939 - val_WER: 0.7629 - lr: 2.5600e-04
# Epoch 34/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.0400 - CER: 0.4294 - WER: 0.7799
# Epoch 34: val_CER did not improve from 0.39392
# 113/113 [==============================] - 26s 225ms/step - loss: 26.0400 - CER: 0.4294 - WER: 0.7799 - val_loss: 27.6803 - val_CER: 0.4305 - val_WER: 0.7412 - lr: 2.5600e-04
# Epoch 35/1000
# 113/113 [==============================] - ETA: 0s - loss: 26.1340 - CER: 0.4233 - WER: 0.7730
# Epoch 35: val_CER did not improve from 0.39392
# 113/113 [==============================] - 23s 192ms/step - loss: 26.1340 - CER: 0.4233 - WER: 0.7730 - val_loss: 24.7822 - val_CER: 0.3997 - val_WER: 0.7860 - lr: 2.5600e-04
# Epoch 36/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.6786 - CER: 0.4178 - WER: 0.7692
# Epoch 36: val_CER did not improve from 0.39392
# 113/113 [==============================] - 25s 216ms/step - loss: 24.6786 - CER: 0.4178 - WER: 0.7692 - val_loss: 23.6665 - val_CER: 0.4085 - val_WER: 0.7726 - lr: 2.5600e-04
# Epoch 37/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.9059 - CER: 0.4191 - WER: 0.7724
# Epoch 37: val_CER did not improve from 0.39392
# 113/113 [==============================] - 22s 191ms/step - loss: 24.9059 - CER: 0.4191 - WER: 0.7724 - val_loss: 23.6366 - val_CER: 0.3980 - val_WER: 0.7776 - lr: 2.5600e-04
# Epoch 38/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.3729 - CER: 0.4167 - WER: 0.7759
# Epoch 38: val_CER did not improve from 0.39392
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00020480002276599408.
# 113/113 [==============================] - 25s 216ms/step - loss: 24.3729 - CER: 0.4167 - WER: 0.7759 - val_loss: 24.3579 - val_CER: 0.4219 - val_WER: 0.7395 - lr: 2.5600e-04
# Epoch 39/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.7835 - CER: 0.4182 - WER: 0.7729
# Epoch 39: val_CER did not improve from 0.39392
# 113/113 [==============================] - 28s 239ms/step - loss: 24.7835 - CER: 0.4182 - WER: 0.7729 - val_loss: 25.1843 - val_CER: 0.4072 - val_WER: 0.7743 - lr: 2.0480e-04
# Epoch 40/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.8013 - CER: 0.4158 - WER: 0.7767
# Epoch 40: val_CER did not improve from 0.39392
# 113/113 [==============================] - 24s 202ms/step - loss: 24.8013 - CER: 0.4158 - WER: 0.7767 - val_loss: 24.1471 - val_CER: 0.4128 - val_WER: 0.7645 - lr: 2.0480e-04
# Epoch 41/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.5230 - CER: 0.4130 - WER: 0.7750
# Epoch 41: val_CER did not improve from 0.39392
# 113/113 [==============================] - 24s 203ms/step - loss: 24.5230 - CER: 0.4130 - WER: 0.7750 - val_loss: 24.0710 - val_CER: 0.3982 - val_WER: 0.7379 - lr: 2.0480e-04
# Epoch 42/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.7953 - CER: 0.4169 - WER: 0.7713
# Epoch 42: val_CER did not improve from 0.39392
# 113/113 [==============================] - 24s 204ms/step - loss: 24.7953 - CER: 0.4169 - WER: 0.7713 - val_loss: 25.2503 - val_CER: 0.4104 - val_WER: 0.7362 - lr: 2.0480e-04
# Epoch 43/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.0845 - CER: 0.4153 - WER: 0.7733
# Epoch 43: val_CER did not improve from 0.39392
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00016384001355618238.
# 113/113 [==============================] - 23s 197ms/step - loss: 25.0845 - CER: 0.4153 - WER: 0.7733 - val_loss: 24.6953 - val_CER: 0.4120 - val_WER: 0.7014 - lr: 2.0480e-04
# Epoch 44/1000
# 113/113 [==============================] - ETA: 0s - loss: 25.4600 - CER: 0.4181 - WER: 0.7720
# Epoch 44: val_CER did not improve from 0.39392
# 113/113 [==============================] - 23s 192ms/step - loss: 25.4600 - CER: 0.4181 - WER: 0.7720 - val_loss: 24.5394 - val_CER: 0.4055 - val_WER: 0.7364 - lr: 1.6384e-04
# Epoch 45/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.8833 - CER: 0.4154 - WER: 0.7750
# Epoch 45: val_CER did not improve from 0.39392
# 113/113 [==============================] - 25s 216ms/step - loss: 24.8833 - CER: 0.4154 - WER: 0.7750 - val_loss: 24.2578 - val_CER: 0.4165 - val_WER: 0.7445 - lr: 1.6384e-04
# Epoch 46/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.1038 - CER: 0.4098 - WER: 0.7709
# Epoch 46: val_CER did not improve from 0.39392
# 113/113 [==============================] - 23s 192ms/step - loss: 24.1038 - CER: 0.4098 - WER: 0.7709 - val_loss: 23.1567 - val_CER: 0.4054 - val_WER: 0.7529 - lr: 1.6384e-04
# Epoch 47/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.9083 - CER: 0.4091 - WER: 0.7718
# Epoch 47: val_CER improved from 0.39392 to 0.39288, saving model to Models/05_sound_to_text/202310062339/model.h5
# 113/113 [==============================] - 24s 205ms/step - loss: 23.9083 - CER: 0.4091 - WER: 0.7718 - val_loss: 23.3992 - val_CER: 0.3929 - val_WER: 0.7679 - lr: 1.6384e-04
# Epoch 48/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.2619 - CER: 0.4110 - WER: 0.7818
# Epoch 48: val_CER did not improve from 0.39288
# 113/113 [==============================] - 23s 198ms/step - loss: 24.2619 - CER: 0.4110 - WER: 0.7818 - val_loss: 23.8017 - val_CER: 0.4154 - val_WER: 0.7412 - lr: 1.6384e-04
# Epoch 49/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.2556 - CER: 0.4103 - WER: 0.7744
# Epoch 49: val_CER did not improve from 0.39288
# 113/113 [==============================] - 29s 254ms/step - loss: 24.2556 - CER: 0.4103 - WER: 0.7744 - val_loss: 23.6439 - val_CER: 0.3975 - val_WER: 0.7745 - lr: 1.6384e-04
# Epoch 50/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.2199 - CER: 0.4081 - WER: 0.7744
# Epoch 50: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 202ms/step - loss: 24.2199 - CER: 0.4081 - WER: 0.7744 - val_loss: 23.5988 - val_CER: 0.4000 - val_WER: 0.7679 - lr: 1.6384e-04
# Epoch 51/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.8924 - CER: 0.4098 - WER: 0.7709
# Epoch 51: val_CER did not improve from 0.39288
# 113/113 [==============================] - 23s 196ms/step - loss: 23.8924 - CER: 0.4098 - WER: 0.7709 - val_loss: 23.3600 - val_CER: 0.4000 - val_WER: 0.7329 - lr: 1.6384e-04
# Epoch 52/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.7187 - CER: 0.4077 - WER: 0.7740
# Epoch 52: val_CER did not improve from 0.39288
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001310720108449459.
# 113/113 [==============================] - 24s 199ms/step - loss: 23.7187 - CER: 0.4077 - WER: 0.7740 - val_loss: 23.3663 - val_CER: 0.3951 - val_WER: 0.7162 - lr: 1.6384e-04
# Epoch 53/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.1964 - CER: 0.4101 - WER: 0.7709
# Epoch 53: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 202ms/step - loss: 24.1964 - CER: 0.4101 - WER: 0.7709 - val_loss: 24.0872 - val_CER: 0.4137 - val_WER: 0.7379 - lr: 1.3107e-04
# Epoch 54/1000
# 113/113 [==============================] - ETA: 0s - loss: 24.2433 - CER: 0.4088 - WER: 0.7728
# Epoch 54: val_CER did not improve from 0.39288
# 113/113 [==============================] - 26s 222ms/step - loss: 24.2433 - CER: 0.4088 - WER: 0.7728 - val_loss: 23.5178 - val_CER: 0.3978 - val_WER: 0.7545 - lr: 1.3107e-04
# Epoch 55/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.9164 - CER: 0.4080 - WER: 0.7754
# Epoch 55: val_CER did not improve from 0.39288
# 113/113 [==============================] - 23s 194ms/step - loss: 23.9164 - CER: 0.4080 - WER: 0.7754 - val_loss: 23.4415 - val_CER: 0.4027 - val_WER: 0.7626 - lr: 1.3107e-04
# Epoch 56/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.3962 - CER: 0.4041 - WER: 0.7726
# Epoch 56: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 202ms/step - loss: 23.3962 - CER: 0.4041 - WER: 0.7726 - val_loss: 23.2031 - val_CER: 0.3954 - val_WER: 0.7198 - lr: 1.3107e-04
# Epoch 57/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.5138 - CER: 0.4094 - WER: 0.7702
# Epoch 57: val_CER did not improve from 0.39288
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.00010485760867595673.
# 113/113 [==============================] - 24s 203ms/step - loss: 23.5138 - CER: 0.4094 - WER: 0.7702 - val_loss: 23.0181 - val_CER: 0.4064 - val_WER: 0.7679 - lr: 1.3107e-04
# Epoch 58/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4759 - CER: 0.4077 - WER: 0.7705
# Epoch 58: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 201ms/step - loss: 23.4759 - CER: 0.4077 - WER: 0.7705 - val_loss: 22.9450 - val_CER: 0.4047 - val_WER: 0.7512 - lr: 1.0486e-04
# Epoch 59/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4947 - CER: 0.4083 - WER: 0.7741
# Epoch 59: val_CER did not improve from 0.39288
# 113/113 [==============================] - 28s 242ms/step - loss: 23.4947 - CER: 0.4083 - WER: 0.7741 - val_loss: 22.8650 - val_CER: 0.3956 - val_WER: 0.7562 - lr: 1.0486e-04
# Epoch 60/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4344 - CER: 0.4101 - WER: 0.7746
# Epoch 60: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 209ms/step - loss: 23.4344 - CER: 0.4101 - WER: 0.7746 - val_loss: 22.9194 - val_CER: 0.3956 - val_WER: 0.7562 - lr: 1.0486e-04
# Epoch 61/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4405 - CER: 0.4053 - WER: 0.7666
# Epoch 61: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 202ms/step - loss: 23.4405 - CER: 0.4053 - WER: 0.7666 - val_loss: 23.0269 - val_CER: 0.4059 - val_WER: 0.7662 - lr: 1.0486e-04
# Epoch 62/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.5842 - CER: 0.4055 - WER: 0.7724
# Epoch 62: val_CER did not improve from 0.39288
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 8.388608694076538e-05.
# 113/113 [==============================] - 24s 208ms/step - loss: 23.5842 - CER: 0.4055 - WER: 0.7724 - val_loss: 22.7672 - val_CER: 0.4067 - val_WER: 0.7512 - lr: 1.0486e-04
# Epoch 63/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.3653 - CER: 0.4078 - WER: 0.7720
# Epoch 63: val_CER did not improve from 0.39288
# 113/113 [==============================] - 28s 241ms/step - loss: 23.3653 - CER: 0.4078 - WER: 0.7720 - val_loss: 22.8975 - val_CER: 0.4110 - val_WER: 0.7295 - lr: 8.3886e-05
# Epoch 64/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4014 - CER: 0.4091 - WER: 0.7703
# Epoch 64: val_CER did not improve from 0.39288
# 113/113 [==============================] - 26s 226ms/step - loss: 23.4014 - CER: 0.4091 - WER: 0.7703 - val_loss: 22.8401 - val_CER: 0.4016 - val_WER: 0.7626 - lr: 8.3886e-05
# Epoch 65/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.3855 - CER: 0.4068 - WER: 0.7758
# Epoch 65: val_CER did not improve from 0.39288
# 113/113 [==============================] - 22s 192ms/step - loss: 23.3855 - CER: 0.4068 - WER: 0.7758 - val_loss: 22.8455 - val_CER: 0.4111 - val_WER: 0.7693 - lr: 8.3886e-05
# Epoch 66/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.2172 - CER: 0.4052 - WER: 0.7734
# Epoch 66: val_CER did not improve from 0.39288
# 113/113 [==============================] - 24s 199ms/step - loss: 23.2172 - CER: 0.4052 - WER: 0.7734 - val_loss: 22.7775 - val_CER: 0.4040 - val_WER: 0.7426 - lr: 8.3886e-05
# Epoch 67/1000
# 113/113 [==============================] - ETA: 0s - loss: 23.4421 - CER: 0.4047 - WER: 0.7757
# Epoch 67: val_CER did not improve from 0.39288
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 6.710886955261231e-05.
# 113/113 [==============================] - 24s 201ms/step - loss: 23.4421 - CER: 0.4047 - WER: 0.7757 - val_loss: 22.8464 - val_CER: 0.4014 - val_WER: 0.7693 - lr: 8.3886e-05
# Epoch 67: early stopping

# %%
import typing
import numpy as np

from mltu.inferenceModel import OnnxInferenceModel
from mltu.preprocessors import WavReader
from mltu.utils.text_utils import ctc_decoder, get_cer, get_wer

class WavToTextModel(OnnxInferenceModel):
    def __init__(self, char_list: typing.Union[str, list], *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.char_list = char_list

    def predict(self, data: np.ndarray):
        data_pred = np.expand_dims(data, axis=0)

        preds = self.model.run(None, {self.input_name: data_pred})[0]

        text = ctc_decoder(preds, self.char_list)[0]

        return text

# %%
train_data_provider.to_csv(os.path.join(configs.model_path, "train.csv"))
val_data_provider.to_csv(os.path.join(configs.model_path, "val.csv"))

# %%
configs = BaseModelConfigs.load("Models/05_sound_to_text/202310062238/configs.yaml")

model = WavToTextModel(model_path=configs.model_path, char_list=configs.vocab, force_cpu=False)

df = pd.read_csv("Models/05_sound_to_text/202310062238/val.csv").values.tolist()

# %%
accum_cer, accum_wer = [], []
for wav_path, label in df:

    spectrogram = WavReader.get_spectrogram(wav_path, frame_length=configs.frame_length, frame_step=configs.frame_step, fft_length=configs.fft_length)
    # WavReader.plot_raw_audio(wav_path, label)

    padded_spectrogram = np.pad(spectrogram, ((0, configs.max_spectrogram_length - spectrogram.shape[0]),(0,0)), mode="constant", constant_values=0)

    # WavReader.plot_spectrogram(spectrogram, label)

    text = model.predict(padded_spectrogram)

    true_label = "".join([l for l in label.lower() if l in configs.vocab])
    if text[((len(text)//4)):]==true_label[((len(text)//4)):]:
      print(f"predicted :: {text},\n True :: {true_label}")



    cer = get_cer(text, true_label)
    wer = get_wer(text, true_label)

    accum_cer.append(cer)
    accum_wer.append(wer)

print(f"Average CER: {np.average(accum_cer)}, Average WER: {np.average(accum_wer)}")
# Out:
# Average CER: 0.41068229180535554, Average WER: 0.7902645502645503

# %%
# !zip -r /content/models_4_58.zip /content/Models
# Out:
#   adding: content/Models/ (stored 0%)
#   adding: content/Models/05_sound_to_text/ (stored 0%)
#   adding: content/Models/05_sound_to_text/202310062238/ (stored 0%)
#   adding: content/Models/05_sound_to_text/202310062238/logs/ (stored 0%)
#   adding: content/Models/05_sound_to_text/202310062238/logs/validation/ (stored 0%)
#   adding: content/Models/05_sound_to_text/202310062238/logs/validation/events.out.tfevents.1696632111.5ad6962bf640.317.1.v2 (deflated 78%)
#   adding: content/Models/05_sound_to_text/202310062238/logs/train/ (stored 0%)
#   adding: content/Models/05_sound_to_text/202310062238/logs/train/events.out.tfevents.1696632053.5ad6962bf640.317.0.v2 (deflated 84%)
#   adding: content/Models/05_sound_to_text/202310062238/configs.yaml (deflated 28%)
#   adding: content/Models/05_sound_to_text/202310062238/val.csv (deflated 78%)
#   adding: content/Models/05_sound_to_text/202310062238/train.csv (deflated 82%)
#   adding: content/Models/05_sound_to_text/202310062238/logs.log (deflated 69%)
#   adding: content/Models/05_sound_to_text/202310062238/model.h5 (deflated 7%)
#   adding: content/Models/05_sound_to_text/202310062238/model.onnx (deflated 8%)

# %%
from google.colab import files
files.download("/content/models_4_58.zip")
